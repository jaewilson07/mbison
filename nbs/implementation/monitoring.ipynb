# %%
#| default_exp implementation.monitoring

# %% [markdown]
# # Monitoring Source Code Project
#
# This implementation wraps `feature.codeengine` and `feature.enterprise_apps` to sync user generated code to an appdb collection
#
# - [x] - implement a class `DocumentSource` for capturing source code.
#     - [x] classmethod for creating `DocumentSource.from_codeengine_package_version`
#         - retrieves most recent version of codeengine package
#
#     - [x] classmethod for creating `DocumentSource.from_source_file`
#         - [ ] workflow for enterprise apps? - one enterprise app can have multiple source_files.  Will need to consider how to structure documents in collection.
#             - in this sample implementation apps shared with the user will be downloaded to the folder TEST
#             - [ ] create workflow for auto sharing all content with the user
#
#         - [ ] workflow for jupyter notebooks? - currently cannot properly automate as unable to retrieve content from jupyter workspaces without the authentication token which must be scraped from the UI
#
# - [ ] - write to AppDb Collection
#     - Not started yet

# %%
#| exporti

from dataclasses import dataclass, field

from typing import List
import datetime as dt

import mbison.client.core as dmda
import mbison.feature.users as dmdu

import mbison.feature.codeengine as dmce
import mbison.feature.enterprise_apps as dmap

import mbison.utils as dmut

# %%
#| hide
import nbdev

import os
from pprint import pprint

# %%
auth = dmda.DomoAuth(
    domo_instance=os.environ["DOMO_INSTANCE"],
    access_token=os.environ["DOMO_ACCESS_TOKEN"],
)
auth
# Out:
# *** Using Access Token Auth
# DomoAuth(domo_instance='domo-community', username=None)

# %%
# | export


class SourceCode_Enum:
    """captures metadata about where source came from"""
    CODE_ENGINE = "Code Engine"
    ENTERPRISE_APP = "Enterprise App"


@dataclass
class DocumentSource:
    environment: SourceCode_Enum
    id: str
    name: str
    design_id: str
    design_name: str
    log_dt: dt.datetime
    code: str
    version: str
    last_modified_dt: dt.datetime
    domo_instance: str
    owner: str

    def __eq__(self, other):
        if not self.__class__.__name__ == other.__class__.__name__:
            return False

        return self.id == other.id and self.environment == other.environment

    @classmethod
    def from_codeengine_package_version(
        cls, dce_package: dmce.DomoCodeEngine_Package, log_dt: dt.datetime = None
    ):

        log_dt = log_dt or dt.datetime.now()

        dce_current_version = dce_package.get_current_version()

        # from pprint import pprint
        # pprint({"version": dce_current_version,
        #        "owner" : dce_package.owner})

        owner = None
        try:
            owner = dmdu.DomoUser.get_by_id(
                auth=dce_package.auth, user_id=dce_package.owner
            )

        except dmdu.User_API_Exception as e:
            print(e)

        return cls(
            environment=SourceCode_Enum.CODE_ENGINE,
            id=dce_package.id,
            name=dce_package.name,
            design_id=dce_package.id,
            design_name=dce_package.name,
            log_dt=log_dt,
            code=dce_current_version.code,
            version=dce_current_version.version,
            last_modified_dt=dce_package.updated_on_dt,
            domo_instance=dce_package.auth.domo_instance,
            owner=owner,
        )

    @classmethod
    def from_source_file(
        cls,
        file_path,
        design_id,
        design_name,
        domo_instance: str,
        owner: dmdu.DomoUser,
        log_dt: dt.datetime = None,
        version: str = None,
        last_modified_dt: dt.datetime = None,
    ):

        with open(file_path, "r") as f:
            code = f.read()

        log_dt = log_dt or dt.datetime.now()

        return cls(
            id=file_path,
            name=os.path.split(file_path)[-1],
            design_id=design_id,
            design_name=design_name,
            log_dt=log_dt,
            code=code,
            version=version,
            last_modified_dt=last_modified_dt,
            domo_instance=domo_instance,
            owner=owner,
            environment=SourceCode_Enum.ENTERPRISE_APP,
        )

        # custom_app, design_version, appdb_collection):
        # document["ID"] = custom_app["id"]
        # document["Name"] = custom_app["name"]
        # document["Published Date"] = custom_app["updatedDate"]


@dataclass
class DocumentSources:
    auth: dmda.DomoAuth
    documents: List[DocumentSource] = field(default_factory=lambda: [])

    log_dt: dt.datetime = dt.datetime.now()

    def get_codeengine(self):
        domo_codenegine_packages = dmce.DomoCodeEngine_Packages(
            auth=self.auth
        ).get_packages()

        documents = [
            DocumentSource.from_codeengine_package_version(
                dce_package=dce_package, log_dt=self.log_dt
            )
            for dce_package in domo_codenegine_packages
        ]

        [self.add_document(document) for document in documents]

        return self.documents

    @staticmethod
    def _download_custom_app_sourcecode(app, download_folder, debug_api: bool = False):
            zip_name = "_package.zip"
            _download_folder = f"{download_folder}/{app.name}/{app.current_version}"

            try:
                res = app.get_source_code(download_folder=_download_folder, file_name=zip_name, debug_api = debug_api)
                
                zip_file_path=os.path.join(
                        _download_folder, zip_name
                    )
                
                path_ls = dmut.download_zip(
                    output_folder=_download_folder,
                    zip_file_path=zip_file_path,
                )

                res.response = path_ls

                return res
            
            except dmap.App_API_Exception as e:
                print(e)
                return False


    def get_custom_apps(self, download_folder="./EXPORT", debug_api : bool = False):
        domo_apps = dmap.DomoEnterpriseApps(auth=self.auth).get_apps()

        return [self._download_custom_app_sourcecode(app = app, download_folder = download_folder, debug_api = debug_api) for app in domo_apps]            


    def add_document(self, document: DocumentSource):
        if document in self.documents:
            return False

        self.documents.append(document)
        return True

# %%
document_sources = DocumentSources(auth= auth)

res_ls = document_sources.get_custom_apps(download_folder= '../../TEST/' ,debug_api = False)
[res for res in res_ls if res ][0:5]
# Out:
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/e09d6625-3680-4fac-bc71-1cd81607eb9a/versions/1.0.7/assets', 'toe': 'N8F2DSTNEU-6RID7-TOS5H'}, is_success=False, status=403)
# unable to download assets for e09d6625-3680-4fac-bc71-1cd81607eb9a || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/f0b9f8b5-3dac-43c1-8e6e-fe2a7c8e248e/versions/1.0.0/assets', 'toe': 'RNVEY0AST2-LUJPO-FBC8A'}, is_success=False, status=403)
# unable to download assets for f0b9f8b5-3dac-43c1-8e6e-fe2a7c8e248e || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/e2fca4a6-f099-4bba-8163-1b88fb53d427/versions/5.1.4/assets', 'toe': 'V0BEFCZHUH-YNM94-FD8H0'}, is_success=False, status=403)
# unable to download assets for e2fca4a6-f099-4bba-8163-1b88fb53d427 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/883bec29-4d9c-4caf-b144-9b3a6d07a001/versions/3.2.7/assets', 'toe': 'ISW4FQP0KE-C3NV2-6VA2D'}, is_success=False, status=403)
# unable to download assets for 883bec29-4d9c-4caf-b144-9b3a6d07a001 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/c5aa00cc-8c6b-4571-a5cf-6ae5ddcf56a8/versions/0.1.0/assets', 'toe': 'FUB7JDXCCV-NXAXK-Q1E13'}, is_success=False, status=403)
# unable to download assets for c5aa00cc-8c6b-4571-a5cf-6ae5ddcf56a8 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/661c932c-0d0c-41c7-890f-d7ea136dad03/versions/0.1.0/assets', 'toe': 'FJL5CPMI19-AH1LX-HLY0K'}, is_success=False, status=403)
# unable to download assets for 661c932c-0d0c-41c7-890f-d7ea136dad03 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/da99ad7c-172f-4153-b67f-1d0e44d20cc9/versions/0.0.1/assets', 'toe': '59P7DJIALM-UEZER-27D5M'}, is_success=False, status=403)
# unable to download assets for da99ad7c-172f-4153-b67f-1d0e44d20cc9 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/9f01fe59-1a82-4964-b9f7-2eadbe0eda29/versions/0.0.1/assets', 'toe': '7LX0TILDYE-N2ARB-XCFKA'}, is_success=False, status=403)
# unable to download assets for 9f01fe59-1a82-4964-b9f7-2eadbe0eda29 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/0668b2ed-5fbb-4868-89bb-8e957f9c9485/versions/1.0.0/assets', 'toe': '5PX5MB45KL-7TUZQ-GDEXD'}, is_success=False, status=403)
# unable to download assets for 0668b2ed-5fbb-4868-89bb-8e957f9c9485 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/b5dc1f18-46cd-4943-bd10-8cb36726da6e/versions/1.0.0/assets', 'toe': 'TYEDMG1L11-9WUVY-J2VYB'}, is_success=False, status=403)
# unable to download assets for b5dc1f18-46cd-4943-bd10-8cb36726da6e || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/af3fe7a9-ece1-4629-90f6-d9b1592f7752/versions/0.1.0/assets', 'toe': '9A4CI2CW80-VV82F-2JQYE'}, is_success=False, status=403)
# unable to download assets for af3fe7a9-ece1-4629-90f6-d9b1592f7752 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/8d9afcdf-223d-4e4d-be2d-248e4fe520e7/versions/0.0.1/assets', 'toe': '47GS6XQ1OR-P14RJ-4VLFS'}, is_success=False, status=403)
# unable to download assets for 8d9afcdf-223d-4e4d-be2d-248e4fe520e7 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/104e7b6e-0a4e-444f-a3ce-3b1b8bd2d25c/versions/0.0.3/assets', 'toe': 'U87Z5PDZPF-HQ0UE-NSE9H'}, is_success=False, status=403)
# unable to download assets for 104e7b6e-0a4e-444f-a3ce-3b1b8bd2d25c || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/4a8bce72-88ec-4e16-b4b9-cb40ac24ed41/versions/1.3.3/assets', 'toe': 'BDPMG8WSMT-1HJ8O-ML94K'}, is_success=False, status=403)
# unable to download assets for 4a8bce72-88ec-4e16-b4b9-cb40ac24ed41 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/b8643ae9-a25a-4730-b366-bc6d33698241/versions/0.0.3/assets', 'toe': 'RRMQLS31TJ-RPX2M-6MCVT'}, is_success=False, status=403)
# unable to download assets for b8643ae9-a25a-4730-b366-bc6d33698241 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/f48c877c-9a42-4b3a-8208-dfced31125c1/versions/1.0.0/assets', 'toe': 'UU11Q6L8K9-0MYJO-F6F14'}, is_success=False, status=403)
# unable to download assets for f48c877c-9a42-4b3a-8208-dfced31125c1 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/002c292a-6ac1-4dc4-bd65-a041d4bfbe38/versions/1.5.0/assets', 'toe': '6IABLGYGII-DJ4EB-ONUPX'}, is_success=False, status=403)
# unable to download assets for 002c292a-6ac1-4dc4-bd65-a041d4bfbe38 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/ef8a7fc5-ce29-4d6f-a71f-eab16c063cbd/versions/1.6.0/assets', 'toe': '7AF31RWMHI-WUX3P-XBI7Z'}, is_success=False, status=403)
# unable to download assets for ef8a7fc5-ce29-4d6f-a71f-eab16c063cbd || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs
|| 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/9a8ea2dc-9c4c-448d-b509-12edb9e4c7d9/versions/1.0.0/assets', 'toe': '9JKI7ZZF3Z-O3IY4-E0WF5'}, is_success=False, status=403)
# unable to download assets for 9a8ea2dc-9c4c-448d-b509-12edb9e4c7d9 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/fdbcd9e6-e58e-4d59-bb47-514676d5bef7/versions/1.0.0/assets', 'toe': 'HQXXFO1GUC-W0ZAN-TDHOO'}, is_success=False, status=403)
# unable to download assets for fdbcd9e6-e58e-4d59-bb47-514676d5bef7 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/062c7c32-7367-4e18-ba4e-079ce95a612f/versions/1.0.0/assets', 'toe': 'ZOFVLIPIX4-ZFST6-U2BA1'}, is_success=False, status=403)
# unable to download assets for 062c7c32-7367-4e18-ba4e-079ce95a612f || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/0d7a371b-8f7b-491e-a451-f1f1b6644b05/versions/1.0.0/assets', 'toe': 'DK7P47WUB9-IVRXU-G9NBW'}, is_success=False, status=403)
# unable to download assets for 0d7a371b-8f7b-491e-a451-f1f1b6644b05 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/ca4f1c9f-7648-4470-b5d7-817f8477c719/versions/1.0.0/assets', 'toe': 'E8TDWDINKQ-YEALC-DXA5D'}, is_success=False, status=403)
# unable to download assets for ca4f1c9f-7648-4470-b5d7-817f8477c719 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/54167827-d573-4b37-8df3-697ca155bb60/versions/0.0.1/assets', 'toe': 'UFSUCHPLBY-W60SQ-CICEL'}, is_success=False, status=403)
# unable to download assets for 54167827-d573-4b37-8df3-697ca155bb60 || 403 - Forbidden || domo-community
# ResponseGetData(response={'status': 403, 'statusReason': 'Forbidden', 'path': '/domoapps/designs/bacd09c5-7b01-4b56-9dc1-b2d908ed8b71/versions/0.0.1/assets', 'toe': 'R5NKZ0E71Y-NX24I-LU3F6'}, is_success=False, status=403)
# unable to download assets for bacd09c5-7b01-4b56-9dc1-b2d908ed8b71 || 403 - Forbidden || domo-community
# [ResponseGetData(response=['00_card.html', '00_domoauth.html', '01_deck.html', '03_snake.html', 'base.html', 'blog', 'card.html', 'deck.html', 'index.html', 'listings.json', 'manifest.json', 'nbdevdocumentation', 'robots.txt', 'search.json', 'sitemap.xml', 'site_libs', 'snake.html', 'styles.css', 'thumbnail.png', 'thumbnail.png.jpg', '_package.zip'], is_success=True, status=200)]

# %%
document_sources = DocumentSources(auth= auth)

document_sources.get_codeengine()
# Out:
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1690220187 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1690220187 || 404 - Not Found || domo-community
# unable to find user - 1690220187 || 404 - Not Found || domo-community
# unable to find user - 1690220187 || 404 - Not Found || domo-community
# unable to find user - 1690220187 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1238642890 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1437951404 || 404 - Not Found || domo-community
# unable to find user - 1437951404 || 404 - Not Found || domo-community
# unable to find user - 1926758222 || 404 - Not Found || domo-community
# unable to find user - 1437951404 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# unable to find user - 1658438246 || 404 - Not Found || domo-community
# [DocumentSource(environment='Code Engine', id='3b8f8181-fdbb-4948-b0c4-d6d27ff991d3', name='Hugging Face', design_id='3b8f8181-fdbb-4948-b0c4-d6d27ff991d3', design_name='Hugging Face', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='from transformers import GPT2LMHeadModel, GPT2Tokenizer\nimport torch\n\ndef generate_text(input_text: str) -> str:\n    """\n    Generate text using the GPT-2 model based on input text.\n\n    Args:\n    input_text (str): Input text to seed the text generation.\n\n    Returns:\n    str: Generated text based on the input.\n    """\n    # Load the model and tokenizer\n    model = GPT2LMHeadModel.from_pretrained("gpt2")\n    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")\n\n    # Encode the input text\n    input_ids = tokenizer.encode(input_text, return_tensors="pt")\n\n    # Generate text using the model\n    output = model.generate(\n        input_ids,\n        max_length=100,\n        num_return_sequences=1,\n        pad_token_id=tokenizer.eos_token_id\n    )\n\n    # Decode the output\n    decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)\n\n    return decoded_output\n\n\n    return decoded_output\n\n# Example usage of the function\ninput_text = "Hello, what is today\'s date?"\nresult = generate_text(input_text)\nprint(result)\n', version='1.0.0', last_modified_dt='2024-07-20T12:14:01.139Z', domo_instance='domo-community', owner=DomoUser(id=1728973208, display_name='Peter Shull', role_id=2097317660, email='shullp05@gmail.com')),
#  DocumentSource(environment='Code Engine', id='0f173529-10d9-41d4-a6e6-b4c1b0f32ff9', name='beastmode', design_id='0f173529-10d9-41d4-a6e6-b4c1b0f32ff9', design_name='beastmode', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='import inspect\nimport json\nfrom typing import List\nimport requests\nimport codeengine\n\ndef get_account(auth_name: str) -> dict:\n    return codeengine.get_account(auth_name)\n\n\nclass CodeEngine_RequestError(Exception):\n    def __init__(self, message=None, res=None, url=None):\n        function_name = inspect.stack()[1][3]\n        message = (\n            message or f"{function_name} : {res[\'status\']} - {res[\'response\']} - {url}"\n        )\n\n        super().__init__(message)\n\n\ndef get_full_auth_session_token(\n    username: str, password: str, domo_instance: str\n) -> str:\n\n    url = "/api/content/v2/authentication"\n\n    payload = {\n        "method": "password",\n        "emailAddress": username,\n        "password": password.strip(),\n    }\n\n    res = get_data(\n        url=url,\n        method="post",\n        domo_instance=domo_instance,\n        body=payload,\n        debug_api=False,\n    )\n\n    data = res["response"]\n\n    if not data.get("success") or not data.get("sessionToken"):\n\n        raise CodeEngine_RequestError(\n            "get_full_auth_session_token: no session token returned"\n        )\n\n    return data.get("sessionToken")\n\n\ndef generate_auth_header(auth_name: str, domo_instance: str) -> dict:\n\n    account = get_account(auth_name)\n\n    creds = None\n    access_token = None\n    session_token = None\n\n    if (\n        account["dataProviderType"] == "abstract-credential-store"\n        and account["credentialsType"] == "fields"\n    ):\n        creds = json.loads(account["properties"]["credentials"])\n\n    if account["dataProviderType"] == "domo-access-token":\n        creds = account["properties"]\n\n    if not creds:\n        raise CodeEngine_RequestError(\n            f"account {auth_name} is not of type \'abstract-credential-store\' or domo-access\'token\'"\n        )\n\n    username = creds.get("username", creds.get("DOMO_USERNAME"))\n    password = creds.get("password", creds.get("DOMO_PASSWORD"))\n    access_token = creds.get("domoAccessToken", creds.get("DOMO_ACCESS_TOKEN"))\n    access_token = access_token and access_token.strip()\n\n    if (not username or not password) and not access_token:\n        raise CodeEngine_RequestError(\n            f"credentials stored in an invalid combination in {auth_name}.  Creds must either be stored as username or DOMO_USERNAME and password or DOMO_PASSWORD or store accessToken or DOMO_ACCESS_TOKEN"\n        )\n\n    if username and password:\n        session_token = get_full_auth_session_token(\n            username=username,\n            password=password,\n            domo_instance=domo_instance,\n        )\n\n    if session_token:\n        return {"x-domo-authentication": session_token}\n\n    if access_token:\n        return {"x-domo-developer-token": access_token}\n\n    raise CodeEngine_RequestError("no token returned")\n\n\ndef get_data(\n    url: str,\n    method: str,\n    domo_instance: str = None,\n    auth_name: str = None,\n    params: dict = None,\n    headers: dict = None,\n    body: dict = None,\n    debug_api: bool = False,\n) -> dict:\n\n    domo_instance = (\n        None if domo_instance == "" else domo_instance.replace(".domo.com", "")\n    )\n    auth_name = None if auth_name == "" else auth_name\n\n    headers = headers or {}\n    headers = {\n        "Accept": "application/json",\n        "Content-Type": "application/json",\n        **headers,\n    }\n\n    if domo_instance:\n        url = f"https://{domo_instance}.domo.com/{url[1:]}"\n\n    if domo_instance and auth_name:\n        auth_header = generate_auth_header(\n            auth_name=auth_name, domo_instance=domo_instance\n        )\n        headers = {**headers, **auth_header}\n\n    if debug_api:\n      ...
#  DocumentSource(environment='Code Engine', id='d82de71d-8547-4f7c-b130-6f708cece9b1', name='DOMO Everywhere', design_id='d82de71d-8547-4f7c-b130-6f708cece9b1', design_name='DOMO Everywhere', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const codeengine = require('codeengine');\n\nclass HelperFunctions {\n  static async addAllRowsPermissions(datasets, permissions) {\n    if (!permissions) {\n      permissions = [];\n    }\n    const permissionsDatasetMap = permissions.reduce(function (\n      map,\n      permission,\n    ) {\n      if (!map[permission.datasetId]) {\n        map[permission.datasetId] = true;\n      }\n      return map;\n    }, {});\n    const datasetsMissingPermissions = datasets.filter(function (dataset) {\n      return !permissionsDatasetMap[dataset];\n    });\n    const newPermissions = await Promise.all(\n      datasetsMissingPermissions.map(HelperFunctions.getAllRowsPolicy),\n    );\n    const allPermissions = [...newPermissions, ...permissions];\n\n    return allPermissions;\n  }\n\n  static async getAllRowsPolicy(dataset) {\n    const url = `/api/query/v1/data-control/${dataset}/filter-groups?options=just_open_policy`;\n\n    try {\n      const res = await codeengine.sendRequest('GET', url);\n\n      return {\n        datasetId: res[0].dataSourceId,\n        policyId: res[0].filterGroupId,\n      };\n    } catch (error) {\n      throw error;\n    }\n  }\n\n  static async setPermissions(datasetId, policyId, virtualUsers) {\n    const url = `/api/query/v1/data-control/${datasetId}/filter-groups/${policyId}?options=include_open_policy,load_filters,load_associations`;\n\n    try {\n      const response = await codeengine.sendRequest('GET', url);\n\n      if (!response.resources) {\n        response.resources = {VIRTUAL_USER: []};\n      }\n      if (!response.resources.VIRTUAL_USER) {\n        response.resources.VIRTUAL_USER = [];\n      }\n      if (!response.virtualUserIds) {\n        response.virtualUserIds = [];\n      }\n      response.virtualUserIds = [...response.virtualUserIds, ...virtualUsers];\n\n      response.resources.VIRTUAL_USER = [\n        ...response.resources.VIRTUAL_USER,\n        ...virtualUsers,\n      ];\n      response.changed = true;\n\n      return codeengine.sendRequest('PUT', url, response);\n    } catch (error) {\n      throw error;\n    }\n  }\n\n  static async addPermissions(permissions, subscribers) {\n    if (!permissions) {\n      permissions = [];\n    }\n    const virtualUsers = await Promise.all(\n      subscribers.map(async function (sub) {\n        return getSubscriberByDomain(sub);\n      }),\n    );\n\n    return await Promise.all(\n      permissions.flatMap(function (permission) {\n        if (!permission || !virtualUsers) {\n          return [];\n        }\n        const datasetId = permission.datasetId;\n        const policyId = permission.policyId;\n        return HelperFunctions.setPermissions(\n          datasetId,\n          policyId,\n          virtualUsers,\n        );\n      }),\n    );\n  }\n\n  static async addDomainToPolicies(domains, virtualUsers, datasets) {\n    try {\n      return await Promise.all(\n        datasets.map(async function (ds) {\n          const permissions = await getUsedPolicies(ds, virtualUsers);\n\n          return this.addPermissions(permissions, domains);\n        }),\n      );\n    } catch (error) {\n      throw error;\n    }\n  }\n\n  static async getPublication(pubId) {\n    const url = `/api/publish/v2/publications/${pubId}`;\n\n    try {\n      return await codeengine.sendRequest('GET', url);\n    } catch (error) {\n      throw error;\n    }\n  }\n\n  static async enablePDPForDataset(datasetId) {\n\n    try {\n      const url = `/api/query/v1/data-control/${datasetId}`;\n      const body = {\n        external: false,\n        enabled: true,\n        secured: false\n      };\n\n      return await codeengine.sendRequest('PUT', url, body);\n    } catch (error) {\n      throw error;\n    }\n  }\n\n  static async ...
#  DocumentSource(environment='Code Engine', id='76982f1d-6155-4f5b-8f91-05ee76002a94', name='DOMO OpenAI', design_id='76982f1d-6155-4f5b-8f91-05ee76002a94', design_name='DOMO OpenAI', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='const ENGINE = require("codeengine");\nconst AI_URL = "api/ai/v1";\nconst DATASET_URL = "api/query/v1/execute";\n\n/**\n * Fetch the collection schema from the API and convert it to the format\n * expected by the AI endpoints.\n *\n * @param datasetId text The dataset ID\n * @returns {}[] The collection schema formatted for AI endpoints\n */\nasync function fetchCollectionSchema(datasetId) {\n  const url = `${DATASET_URL}/${datasetId}`;\n\n  const response = await ENGINE.sendRequest("post", url, {\n    sql: "select * from table limit 1",\n  }).catch(console.error);\n\n  const columns = response?.columns?.map((columnName, idx) => ({\n    name: columnName,\n    type: response.metadata[idx].type,\n  }));\n\n  return [\n    {\n      dataSourceName: "table",\n      description: "",\n      columns,\n    },\n  ];\n}\n\n/**\n * Create an SQL query from the input text using the AI endpoint, customized\n * to the schema of the provided dataset.\n *\n * @param input text The text to convert to SQL\n * @param datasetId text The dataset ID\n * @returns text The SQL query created from the input text\n */\nasync function askForSQL(input, datasetId) {\n  const dataSourceSchemas = await fetchCollectionSchema(datasetId);\n  const aiResponse = await ENGINE.sendRequest("post", `${AI_URL}/text/sql`, {\n    input,\n    dataSourceSchemas,\n  });\n\n  return aiResponse?.choices?.[0]?.output ?? "";\n}\n\n/**\n * Create a beastmode from the input text using the AI endpoint, customized\n * to the schema of the provided dataset.\n *\n * @param input text The text to create a beastmode from\n * @param datasetId text The dataset ID\n * @returns text The beastmode created from the input text\n */\nasync function askForBeastmode(input, datasetId) {\n  const dataSourceSchemas = await fetchCollectionSchema(datasetId);\n  const aiResponse = await ENGINE.sendRequest(\n    "post",\n    `${AI_URL}/text/beastmode`,\n    {\n      input,\n      dataSourceSchemas,\n    }\n  );\n\n  return aiResponse?.choices?.[0]?.output ?? "";\n}\n\n/**\n * Create text from the input text using the AI endpoint.\n * \n * @param input text The text to feed to AI\n * @returns\n */\nasync function askForText(input) {\n  const aiResponse = await ENGINE.sendRequest(\n    "post",\n    `${AI_URL}/text/generation`,\n    { input }\n  );\n\n  return aiResponse?.choices?.[0]?.output ?? "";\n}\n\nmodule.exports = {\n  fetchCollectionSchema,\n  askForSQL,\n  askForBeastmode,\n  askForText,\n};\n', version='1.0.0', last_modified_dt='2024-06-11T23:20:48.963Z', domo_instance='domo-community', owner=None),
#  DocumentSource(environment='Code Engine', id='28cabcc8-ebfe-4211-8e4b-d46d9cb620f0', name='DOMO Pages', design_id='28cabcc8-ebfe-4211-8e4b-d46d9cb620f0', design_name='DOMO Pages', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='const codeengine = require(\'codeengine\');\n\n/**\n *\n * @param {number} pageId - The page ID to revoke access\n * @param {Person} person - The person to revoke access from\n * @returns {boolean} success - Whether the revoke access was successful or not\n */\n\nasync function revokePageAccess(pageId, person) {\n  try {\n    await codeengine.sendRequest(\n      \'delete\',\n      `/api/content/v1/share/page/${pageId}/user/${+person}`,\n    );\n\n    return true;\n  } catch (error) {\n    throw error;\n  }\n}\n\n/**\n * Create a new page named "title" that is a child of an existing page as denoted by "parentPageId"\n *\n * @param {text} parentPageId - the parent page of the new page to be created\n * @param {text} title - the new page title\n * @returns {object} page - the new page\n */\nasync function createSubPage(parentPageId, title) {\n  try {\n    const url = \'/api/content/v1/pages\';\n    return await codeengine.sendRequest(\'post\', url, {\n      parentPageId,\n      title,\n      hasLayout: true,\n    });\n  } catch (err) {\n    throw new Error(\n      `Could not create the subpage ${title} for page ${parentPageId}`,\n    );\n  }\n}\n\n/**\n * Move a subpage denoted by "pageId" to be a top-level page\n *\n * @param {number} pageId - The page that is currently a subpage\n * @returns {boolean} success - Whether the move was successful\n */\nasync function makePageTopLevel(pageId) {\n  try {\n    const url = \'/api/content/v1/pages/bulk/move\';\n    await codeengine.sendRequest(\'put\', url, {\n      pageIds: [pageId],\n      pagePermission: \'ORIGINAL\',\n    });\n    return true;\n  } catch (err) {\n    throw new Error(\n      `Could not move the subpage ${pageId} to be a top-level page`,\n    );\n  }\n}\nmodule.exports = {revokePageAccess,createSubPage,makePageTopLevel};', version='1.0.3', last_modified_dt='2024-06-11T23:20:48.959Z', domo_instance='domo-community', owner=None),
#  DocumentSource(environment='Code Engine', id='105d5d48-be5b-4875-931b-d16272b34bd9', name='DOMO Awards', design_id='105d5d48-be5b-4875-931b-d16272b34bd9', design_name='DOMO Awards', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const codeengine = require('codeengine');\n\n/**\n * Grants the specified achievement to the specified person.\n *\n * @param {number} achievementId - the id of the achivement in the company settings of that instance\n * @param {Person} person - the person\n * @returns {boolean} - whether or not it was successful\n */\nasync function grant(achievementId, person) {\n  const url = `/api/content/v2/users/${person}/achievements`;\n  try {\n    await codeengine.sendRequest('post', url, {achievementId: achievementId});\n    return true;\n  } catch (err) {\n    throw new Error(\n      `Failed to award person ${person} the achievement ${achievementId}`,\n    );\n  }\n}\nmodule.exports = {grant};", version='2.0.7', last_modified_dt='2024-06-11T23:20:48.959Z', domo_instance='domo-community', owner=DomoUser(id=27, display_name='DomoSupport', role_id=1, email='support@domo.com')),
#  DocumentSource(environment='Code Engine', id='73733d13-910d-439b-96d2-6735952aec76', name='DOMO Beastmode', design_id='73733d13-910d-439b-96d2-6735952aec76', design_name='DOMO Beastmode', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const codeengine = require('codeengine');\n\n/**\n * Gets the specified Beastmode\n *\n * @param {number} beastmodeId - The id for the beast mode\n * @returns {Object} The beast mode object\n *\n * @throws {Error} If the beast mode is not found\n */\nasync function getBeastmode(beastmodeId) {\n  try {\n    return await codeengine.sendRequest(\n      'get',\n      `api/query/v1/functions/template/${beastmodeId}`,\n    );\n  } catch (error) {\n    throw new Error(\n      `Failed to fetch beast mode for the given beast mode id: ${beastmodeId}`,\n      error,\n    );\n  }\n}\n\n/**\n * Update a Beastmode formula\n *\n * @param {number} beastmodeId - The id for the beast mode\n * @param {text} expression - The text formula to update\n * @returns {boolean} - True if successful\n */\nasync function updateBeastmode(beastmodeId, expression) {\n  const url = `/api/query/v1/functions/template/${beastmodeId}?strict=false`;\n  const payload = {expression};\n  try {\n    await codeengine.sendRequest('PUT', url, payload);\n    return true;\n  } catch (error) {\n    throw error;\n  }\n}\nmodule.exports = {getBeastmode,updateBeastmode};", version='1.0.3', last_modified_dt='2024-06-11T23:20:48.959Z', domo_instance='domo-community', owner=None),
#  DocumentSource(environment='Code Engine', id='f3bc12a7-1001-4582-a344-f331c81841e7', name='DOMO Sandbox', design_id='f3bc12a7-1001-4582-a344-f331c81841e7', design_name='DOMO Sandbox', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const ce = require('codeengine');\n\nclass Sandbox {\n  static MAX_WAIT_MS = 60 * 5 * 1000; // 5 minutes\n\n  /**\n   * Helper function to pause execution for a specified time.\n   *\n   * @param {Function} res - Resolve function for the Promise.\n   * @param {Function} rej - Reject function for the Promise (not used).\n   */\n  static sleepHelper(res, rej) {\n    setTimeout(res, 2000);\n  }\n\n  /**\n   * Pauses execution for 2 seconds.\n   *\n   * @returns {Promise} - Returns a promise that resolves after 2 seconds.\n   */\n  static sleep() {\n    return new Promise(Sandbox.sleepHelper);\n  }\n\n  /**\n   * Validates if the provided data is a boolean.\n   *\n   * @param {any} data - The data to validate.\n   * @param {text} [alias='value'] - The alias for the data in the error message.\n   * @throws {Error} - Throws an error if the data is not a boolean.\n   */\n  static validateBoolean(data, alias = 'value') {\n    if (typeof data !== 'boolean')\n      throw new Error(`Invalid ${alias} boolean value`);\n  }\n\n  /**\n   * Validates if the provided data is text\n   *\n   * @param {any} data - The data to validate.\n   * @param {text} [alias='value'] - The alias for the data in the error message.\n   * @throws {Error} - Throws an error if the data is not text.\n   */\n  static validateString(data, alias = 'value') {\n    if (typeof data !== 'string')\n      throw new Error(`Invalid ${alias} text value`);\n  }\n\n  /**\n   * Validates if the provided UUID is valid.\n   *\n   * @param {text} uuid - The UUID to validate.\n   * @param {text} [alias='uuid'] - The alias for the UUID in the error message.\n   * @throws {Error} - Throws an error if the UUID is not valid.\n   */\n  static validateUUID(uuid, alias = 'uuid') {\n    Sandbox.validateString(uuid, alias);\n    const regex =\n      /^[a-zA-Z\\d]{8}-[a-zA-Z\\d]{4}-[a-zA-Z\\d]{4}-[a-zA-Z\\d]{4}-[a-zA-Z\\d]{12}$/;\n\n    if (!regex.test(uuid)) throw new Error(`Invalid ${alias} uuid value`);\n  }\n\n  /**\n   * Fetches a repository by its ID.\n   *\n   * @param {text} repositoryId - The ID of the repository to fetch.\n   * @returns {Promise} - Returns a promise that resolves with the fetched repository.\n   * @throws {Error} - Throws an error if the repository ID is not a valid UUID.\n   */\n  static _fetchRepositoryById(repositoryId) {\n    try {\n      Sandbox.validateUUID(repositoryId);\n      return ce.sendRequest(\n        'get',\n        `/api/version/v1/repositories/${repositoryId}`,\n      );\n    } catch (error) {\n      console.error(`Failed to fetch repository: ${error.message}`);\n      throw error;\n    }\n  }\n\n  /**\n   * Sorts commits based on their creation date.\n   *\n   * @param {Object} a - The first commit to compare.\n   * @param {Object} b - The second commit to compare.\n   * @returns {number} The difference in time between the two commits.\n   */\n  static sortCommits(a, b) {\n    return new Date(b.created).getTime() - new Date(a.created).getTime();\n  }\n\n  /**\n   * Resolves the last commit from a list of commits.\n   *\n   * @param {Object} param0 - An object containing a list of commits.\n   * @returns {Object} The last commit.\n   */\n  static resolveLastCommit({commits}) {\n    if (!Array.isArray(commits)) throw new Error('Invalid commits array');\n\n    return [...commits].sort(Sandbox.sortCommits)[0];\n  }\n\n  /**\n   * Fetches the last commit from a repository.\n   *\n   * @param {text} repositoryId - The ID of the repository.\n   * @returns {Promise} A promise that resolves with the last commit.\n   */\n  static async fetchLastCommit(repositoryId) {\n    try {\n      Sandbox.validateUUID(repositoryId, 'repositoryId');\n      const response = await ce.sendRequest(\n        'post',\n        `/api/ ...
#  DocumentSource(environment='Code Engine', id='1878946a-dbc0-4f06-891c-b6d7470902e4', name='DOMO Entity Conversion', design_id='1878946a-dbc0-4f06-891c-b6d7470902e4', design_name='DOMO Entity Conversion', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='/**\n * Converts a text user ID to a Person entity.\n *\n * @param {text} userId - the text ID to convert to a Person\n * @returns {Person} - the person ID as a Person entity\n */\nconst convertTextToPerson = userId => userId;\n\n/**\n * Converts a number user ID to a Person entity.\n *\n * @param {number} userId the number ID to convert to a Person\n * @returns {Person} - the person ID as Person entity\n */\nconst convertNumberToPerson = userId => userId;\n\n/**\n * Converts a text group ID to a Group entity.\n *\n * @param {text} groupId - the text ID to convert to a Group\n * @returns {Group} - the group ID as Group entity\n */\nconst convertTextToGroup = groupId => groupId;\n\n/**\n * Converts a number group ID to a Group entity.\n *\n * @param {number} groupId - the number ID to convert to a Group\n * @returns {Group} - the group ID as Group entity\n */\nconst convertNumberToGroup = groupId => groupId;\n\n/**\n * Converts a text dataset ID to a Dataset entity.\n *\n * @param {text} datasetId - the text ID to convert to a Dataset\n * @returns {Dataset} - the dataset ID as Dataset entity\n */\nconst convertTextToDataset = datasetId => datasetId;\nmodule.exports = {convertTextToPerson,convertNumberToPerson,convertTextToGroup,convertNumberToGroup,convertTextToDataset};', version='2.0.0', last_modified_dt='2024-06-11T23:20:48.959Z', domo_instance='domo-community', owner=None),
#  DocumentSource(environment='Code Engine', id='cbbc74e3-7788-4af7-ad81-d10db16bd4b9', name='DOMO Google Sheets', design_id='cbbc74e3-7788-4af7-ad81-d10db16bd4b9', design_name='DOMO Google Sheets', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const axios = require('axios');\nconst codeengine = require('codeengine');\n\nasync function getSheet(googleAccount, sheetId) {\n  const account = await codeengine.getAccount(googleAccount.id);\n  const ACCESS_TOKEN = account.properties.access_token;\n  const url = `https://sheets.googleapis.com/v4/spreadsheets/${sheetId}/values/Sheet1`;\n  const headers = {\n    Authorization: `Bearer ${ACCESS_TOKEN}`,\n  };\n\n  try {\n    const response = await axios.get(url, {\n      headers,\n    });\n\n    return response.data;\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function appendRowWithList(googleAccount, sheetId, values) {\n  const account = await codeengine.getAccount(googleAccount.id);\n  const ACCESS_TOKEN = account.properties.access_token;\n  const url = `https://sheets.googleapis.com/v4/spreadsheets/${sheetId}/values/Sheet1:append?valueInputOption=RAW`;\n  const headers = {\n    Authorization: `Bearer ${ACCESS_TOKEN}`,\n  };\n\n  try {\n    await axios.post(\n      url,\n      {values: [values]},\n      {\n        headers,\n      },\n    );\n\n    return true;\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function appendRowWithObject(googleAccount, sheetId, row){\n  const values = Object.values(row);\n  return appendRowWithList(googleAccount, sheetId, values)\n}\n\nasync function updateRow(googleAccount, sheetId, range, values) {\n  const account = await codeengine.getAccount(googleAccount.id);\n  const ACCESS_TOKEN = account.properties.access_token;\n  const url = `https://sheets.googleapis.com/v4/spreadsheets/${sheetId}/values/Sheet1!${range}?valueInputOption=RAW`;\n  const headers = {\n    Authorization: `Bearer ${ACCESS_TOKEN}`,\n  };\n\n  try {\n    await axios.put(\n      url,\n      {values: [values]},\n      {\n        headers,\n      },\n    );\n\n    return true;\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function deleteRow(googleAccount, sheetId, range) {\n  const account = await codeengine.getAccount(googleAccount.id);\n  const ACCESS_TOKEN = account.properties.access_token;\n  const url = `https://sheets.googleapis.com/v4/spreadsheets/${sheetId}/values/Sheet1!${range}:clear`;\n  const headers = {\n    Authorization: `Bearer ${ACCESS_TOKEN}`,\n  };\n\n  try {\n    await axios.post(\n      url,\n      {},\n      {\n        headers,\n      },\n    );\n\n    return true;\n  } catch (error) {\n    throw error;\n  }\n}\nmodule.exports = {getSheet,appendRowWithList,appendRowWithObject,updateRow,deleteRow};", version='1.0.0', last_modified_dt='2024-06-11T23:20:48.959Z', domo_instance='domo-community', owner=None),
#  DocumentSource(environment='Code Engine', id='a3191dc3-fa6f-4ac0-a40f-645d7f4ce525', name='Microsoft Teams', design_id='a3191dc3-fa6f-4ac0-a40f-645d7f4ce525', design_name='Microsoft Teams', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='const axios = require(\'axios\');\nconst codeengine = require(\'codeengine\');\n\nasync function makeApiRequest(url, accessToken, nextPageURL, previousDataList) {\n  try {\n    const response = await axios.get(nextPageURL || url, {\n      headers: {\n        Authorization: `Bearer ${accessToken}`,\n      },\n    });\n\n    const nextLink = response.data[\'@odata.nextLink\'];\n    const newData = response.data.value || [];\n\n    const dataList = [...(previousDataList || []), ...newData];\n\n    if (nextLink) {\n      return await makeApiRequest(url, accessToken, nextLink, dataList);\n    }\n\n    return dataList;\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function getTeams(teamsAccount) {\n  try {\n    const account = await codeengine.getAccount(teamsAccount.id);\n    const accessToken = account.properties.access_token;\n    return await makeApiRequest(\n      \'https://graph.microsoft.com/v1.0/teams\',\n      accessToken,\n      null,\n      null,\n    );\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function getChannels(teamsAccount, teamId) {\n  try {\n    const accessToken = (await codeengine.getAccount(teamsAccount.id))\n      .properties.access_token;\n    return await makeApiRequest(\n      `https://graph.microsoft.com/beta/teams/${teamId}/channels`,\n      accessToken,\n      null,\n      null,\n    );\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function getChats(teamsAccount) {\n  try {\n    const accessToken = (await codeengine.getAccount(teamsAccount.id))\n      .properties.access_token;\n    return await makeApiRequest(\n      \'https://graph.microsoft.com/beta/me/chats?$expand=members\',\n      accessToken,\n      null,\n      null,\n    );\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function getChatDetails(teamsAccount, chatId) {\n  try {\n    const accessToken = (await codeengine.getAccount(teamsAccount.id))\n      .properties.access_token;\n    const response = await axios.get(\n      `https://graph.microsoft.com/beta/me/chats/${chatId}?$expand=members`,\n      {\n        headers: {\n          Authorization: `Bearer ${accessToken}`,\n        },\n      },\n    );\n\n    return response.data;\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function postMessageToChat(\n  teamsAccount,\n  chatId,\n  message,\n  emailsToMention,\n) {\n  try {\n    const accessToken = (await codeengine.getAccount(teamsAccount.id))\n      .properties.access_token;\n    const mentionsObject = await buildMentionObject(\n      teamsAccount,\n      emailsToMention,\n    );\n    const content = mentionsObject\n      ? `${mentionsObject.mentionText} ${message}`\n      : message;\n\n    const body = {\n      body: {\n        contentType: \'html\',\n        content,\n      },\n      mentions: mentionsObject ? mentionsObject.mentions : undefined,\n    };\n\n    await axios.post(\n      `https://graph.microsoft.com/beta/chats/${chatId}/messages`,\n      body,\n      {\n        headers: {\n          Authorization: `Bearer ${accessToken}`,\n          \'Content-Type\': \'application/json\',\n        },\n      },\n    );\n\n    return true;\n  } catch (error) {\n    throw error;\n  }\n}\n\nasync function postMessageToChannel(\n  teamsAccount,\n  teamId,\n  channelId,\n  message,\n  emailsToMention,\n) {\n  try {\n    const accessToken = (await codeengine.getAccount(teamsAccount.id))\n      .properties.access_token;\n    const mentionsObject = await buildMentionObject(\n      teamsAccount,\n      emailsToMention,\n    );\n    const content = mentionsObject\n      ? `${mentionsObject.mentionText} ${message}`\n      : message;\n\n    const body = {\n      body: {\n        contentType: \'html\',\n        content,\n      },\n      mentions: mention ...
#  DocumentSource(environment='Code Engine', id='b98dd931-4f07-44bc-a3fc-5b96c5dd47bd', name='DOMO Observability Metrics', design_id='b98dd931-4f07-44bc-a3fc-5b96c5dd47bd', design_name='DOMO Observability Metrics', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const codeengine = require('codeengine');\nconst observabilityMetricsAppId = `50e7230f-d2f2-42e2-a208-d94c8ae9f64c`;\n/**\n * Recursively lists all jobs in the Observability Metrics application.\n * It fetches jobs in pages, with a limit of 100 jobs per page.\n * If an error occurs during the fetch, it logs the error and returns an empty array.\n *\n * @param {number} [page=0] - The page number to fetch, starting from 0.\n * @returns {object[]} - An array of job objects.\n * @throws Will throw an error if the request fails.\n */\nasync function listJobs(page = 0) {\n  try {\n    const limit = 100;\n    const offset = page * limit;\n    const result = await codeengine.sendRequest(\n      'get',\n      `/api/executor/v2/applications/${observabilityMetricsAppId}/jobs?limit=${limit}&offset=${offset}`,\n    );\n\n    if (result.totalResults > offset + limit) {\n      const nextJobs = await listJobs(page + 1);\n      return [...result.jobs, ...nextJobs];\n    }\n\n    return result.jobs;\n  } catch (error) {\n    throw `Failed to list jobs: ${error}`;\n  }\n}\n/**\n * Get the job ID by the job name\n *\n * @param {string} jobName - the name of the job\n * @returns {string} - the job ID\n * @throws Will throw an error if no job is found, or if multiple jobs with the same name are found.\n */\nasync function getJobIdByJobName(jobName) {\n  try {\n    const result = await codeengine.sendRequest(\n      'get',\n      `/api/executor/v2/applications/${observabilityMetricsAppId}/jobs?limit=100&offset=0&q=${jobName}`,\n    );\n\n    const matchingJobs = result.jobs.filter(job => job.jobName === jobName);\n\n    if (matchingJobs.length === 0)\n      throw new Error('No job found, make sure jobName is entered correctly');\n\n    if (matchingJobs.length > 1)\n      throw new Error('Duplicate Job Names found, could not return one id');\n\n    return matchingJobs[0].jobId;\n  } catch (error) {\n    throw new Error(`Failed to get job ID by job name: ${error}`);\n  }\n}\n/**\n * Get the account ID by the account name\n *\n * @param {string} accountName - the name of the account\n * @returns {number} - the account ID\n */\nasync function getAccountIdByName(accountName) {\n  try {\n    const payload = {\n      count: 100,\n      query: accountName,\n      entityList: [['account']],\n    };\n    const result = await codeengine.sendRequest(\n      'post',\n      `/api/search/v1/query`,\n      payload,\n    );\n\n    const matchingAccounts = result.searchObjects.filter(\n      account => account.displayName === accountName,\n    );\n\n    if (matchingAccounts.length === 0)\n      throw new Error(\n        'No accounts found. Make sure accountName is entered correctly',\n      );\n\n    if (matchingAccounts.length > 1)\n      throw new Error('Duplicate accounts found, could not return one id');\n\n    return Number(matchingAccounts[0].databaseId);\n  } catch (error) {\n    throw new Error(`Failed to get account ID by account name: ${error}`);\n  }\n}\n/**\n * Create or edit a job\n *\n * @param {string} jobId - the job id\n * @param {string} jobName - the job name\n * @param {string} jobDescription - the job description\n * @param {number} accountId - the account id\n * @param {string} domoInstance - the domo instance\n * @param {object} policies - the policies object\n * @param {string} metricsDataSetId - the metrics dataset id\n * @returns {string} - the job id\n */\nasync function createOrEditJob(\n  jobId,\n  jobName,\n  jobDescription,\n  accountId,\n  domoInstance,\n  policies,\n  metricsDatasetId,\n) {\n  try {\n    const url = `/api/executor/v1/applications/${observabilityMetricsAppId}/jobs`;\n    const jobPayload = {\n      jobId,\n      jobName,\n      jobDescription,\n  ...
#  DocumentSource(environment='Code Engine', id='72c88e1d-c56b-4692-b794-180eae4db289', name='AirTable', design_id='72c88e1d-c56b-4692-b794-180eae4db289', design_name='AirTable', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='const codeengine = require("codeengine");\nconst axios = require("axios");\nconst baseUrl = "https://api.airtable.com/v0";\n\n/**\n * List all bases for the given account\n *\n * @param {Account} account - The AirTable Third Party API Token - https://airtable.com/create/tokens\n * @returns {object[]} An array of bases\n */\nasync function listBases(account) {\n  try {\n    const acc = await codeengine.getAccount(account.id);\n    const url = `${baseUrl}/meta/bases`;\n    const config = {\n      method: \'get\',\n      url,\n      headers: {\n        "Authorization": `Bearer ${acc.properties.apikey}`,\n      }\n    };\n  \n    const response = await axios.request(config);\n    return response.data.bases;\n  } catch (e) {\n    throw e;\n  }\n}\n\n/**\n * Get all tables for a specified base\n *\n * @param {Account} account - The AirTable Third Party API Token - https://airtable.com/create/tokens\n * @param {text} baseId - The ID of the base\n * @returns {object[]} An array of tables\n */\nasync function getBaseTables(account, baseId) {\n  try {\n    const acc = await codeengine.getAccount(account.id);\n    const url = `${baseUrl}/meta/bases/${baseId}/tables`;\n    const config = {\n      method: \'get\',\n      url,\n      headers: {\n        "Authorization": `Bearer ${acc.properties.apikey}`,\n      }\n    };\n  \n    const response = await axios.request(config);\n    return response.data.tables;\n  } catch (e) {\n    console.error(e);\n    throw e;\n  }\n}\n\n/**\n * List all records in a specified table\n *\n * @param {Account} account - The AirTable Third Party API Token - https://airtable.com/create/tokens\n * @param {text} baseId - The ID of the base\n * @param {text} tableName - The name of the table\n * @returns {object[]} An array of records\n */\nasync function listRecords(account, baseId, tableName) {\n  try {\n    const acc = await codeengine.getAccount(account.id);\n    const url = `${baseUrl}/${baseId}/${tableName}`;\n    const config = {\n      method: \'get\',\n      url,\n      headers: {\n        "Authorization": `Bearer ${acc.properties.apikey}`,\n      }\n    };\n  \n    const response = await axios.request(config);\n    return response.data.records;\n    } catch (e) {\n    console.error(e);\n    throw e;\n  }\n}\n\n/**\n * Create a new record in a specified table\n *\n * @param {Account} account - The AirTable Third Party API Token - https://airtable.com/create/tokens\n * @param {text} baseId - The ID of the base\n * @param {text} tableName - The name of the table\n * @param {object} fields - The fields of the new record\n * @returns {object} The created record\n */\nasync function createRecord(account, baseId, tableName, fields) {\n  try {\n    const acc = await codeengine.getAccount(account.id);\n    const url = `${baseUrl}/${baseId}/${tableName}`;\n    const config = {\n      method: \'post\',\n      url,\n      headers: {\n        "Authorization": `Bearer ${acc.properties.apikey}`,\n        "Content-Type": "application/json"\n      },\n      data: {\n        records:[{\n          fields\n        }]\n      }\n    };\n  \n    const response = await axios.request(config);\n    return response.data;\n  } catch (e) {\n    console.error(e);\n    throw e;\n  }\n}\n\n/**\n * Update an existing record in a specified table\n *\n * @param {Account} account - The AirTable Third Party API Token - https://airtable.com/create/tokens\n * @param {text} baseId - The ID of the base\n * @param {text} tableName - The name of the table\n * @param {text} recordId - The ID of the record to update\n * @param {object} fields - The fields to update\n * @returns {object} The updated record\n */\nasync function updateRecord(account, baseId, tableName, recordId, fields) {\n  try {\n    const acc = ...
#  DocumentSource(environment='Code Engine', id='b798f2c5-677f-4255-9c17-0d97d6ae9d49', name='Asana', design_id='b798f2c5-677f-4255-9c17-0d97d6ae9d49', design_name='Asana', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="const codeengine = require('codeengine');\nconst axios = require('axios');\n\n/**\n * Makes an API request to the specified URL with the provided access token\n *\n * @param {text} url - The URL for the API request\n * @param {text} accessToken - The access token\n * @param {text} method - The HTTP method to use for the request (e.g., 'GET', 'POST', 'PUT', 'DELETE')\n * @param {object} [data] - The data to send with the request (for methods like POST, PUT)\n * @returns {object} - The response data from the API request\n * @throws {Error} - Throws an error if the request fails\n */\nasync function makeApiRequest(url, accessToken, method, data = null) {\n  try {\n    const response = await axios({\n      url: url,\n      method: method,\n      headers: {\n        Authorization: `Bearer ${accessToken}`,\n        'Content-Type': 'application/json',\n      },\n      ...(data !== null && {data}),\n    });\n    return response.data;\n  } catch (error) {\n    console.error(error.response.data || error);\n    throw error;\n  }\n}\n\n/**\n * Get details on a project\n *\n * @param {text} projectId - The Asana project ID\n * @param {Account} asanaAccount - Your Asana account\n * @returns {object} - The project information\n */\nasync function getProjectInfo(projectId, asanaAccount) {\n  const account = await codeengine.getAccount(asanaAccount.id);\n  const accessToken = account.properties.access_token;\n  const url = `https://app.asana.com/api/1.0/projects/${projectId}`;\n  return (await makeApiRequest(url, accessToken, 'GET')).data;\n}\n\n/**\n * Get tasks in a project\n *\n * @param {text} projectId - The Asana project ID\n * @param {Account} asanaAccount - Your Asana account\n * @returns {object} - The project tasks\n */\nasync function getProjectTasks(projectId, asanaAccount) {\n  const account = await codeengine.getAccount(asanaAccount.id);\n  const accessToken = account.properties.access_token;\n  const url = `https://app.asana.com/api/1.0/projects/${projectId}/tasks`;\n  return (await makeApiRequest(url, accessToken, 'GET')).data;\n}\n\n/**\n * Get details for a task\n *\n * @param {text} taskId - The Asana task ID\n * @param {Account} asanaAccount - Your Asana account\n * @returns {object} - The task information\n */\nasync function getTaskInfo(taskId, asanaAccount) {\n  const account = await codeengine.getAccount(asanaAccount.id);\n  const accessToken = account.properties.access_token;\n  const url = `https://app.asana.com/api/1.0/tasks/${taskId}`;\n  return (await makeApiRequest(url, accessToken, 'GET')).data;\n}\n\n/**\n * Update properties on a task\n *\n * @param {text} taskId - The Asana task ID\n * @param {object} updatedTask - The updated task object\n * @param {Account} asanaAccount - Your Asana account\n * @returns {object} - The updated task information\n */\nasync function updateTask(taskId, updatedTask, asanaAccount) {\n  const account = await codeengine.getAccount(asanaAccount.id);\n  const accessToken = account.properties.access_token;\n  const url = `https://app.asana.com/api/1.0/tasks/${taskId}`;\n  const body = {\n    data: updatedTask,\n  };\n  return (await makeApiRequest(url, accessToken, 'PUT', body)).data;\n}\n\n/**\n * Get comments on a task\n *\n * @param {text} taskId - The Asana task ID\n * @param {Account} asanaAccount - Your Asana account\n * @returns {object} - The comments on the task\n */\nasync function getTaskComments(taskId, asanaAccount) {\n  const account = await codeengine.getAccount(asanaAccount.id);\n  const accessToken = account.properties.access_token;\n  const url = `https://app.asana.com/api/1.0/tasks/${taskId}/stories`;\n  return (await makeApiRequest(url, accessToken, 'GET')).data;\n}\n\n/**\n * Get subtasks for a task\n *\n * @param {text} taskId - The ...
#  DocumentSource(environment='Code Engine', id='3af40f18-331a-4073-a25f-a6b326a30fb7', name='BigQuery', design_id='3af40f18-331a-4073-a25f-a6b326a30fb7', design_name='BigQuery', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='const codeengine = require(\'codeengine\');\nconst baseAPI = \'https://bigquery.googleapis.com\';\n\n/**\n* A private function to form BigQuery http requests\n*/\nasync function request(serviceAccount, requestConfig) {\n  const acc = await codeengine.getAccount(serviceAccount.id);\n  const keys = JSON.parse(acc.properties.serviceToken);\n  const {JWT} = codeengine.googleAuthLibrary;\n  const config = {\n    email: keys.client_email,\n    key: keys.private_key,\n    scopes: [\'https://www.googleapis.com/auth/cloud-platform\'],\n  };\n  const client = new JWT(config);\n  return await client.request(requestConfig);\n}\n\n/**\n* List projects\n*\n* @param {Account} serviceAccount - the service account for your BigQuery package: https://cloud.google.com/iam/docs/service-accounts-create#creating\n* @returns {object[]} - A list of projects that the service account has access to\n*/\nasync function listProjects(serviceAccount) {\n  try {\n    const url = `${baseAPI}/bigquery/v2/projects/`;\n    const response = await request(serviceAccount, {url});\n    return response.data.projects;\n  } catch (e) {\n    console.error(e)\n    throw(e);\n  }\n}\n\n/**\n* List datasets\n*\n* @param {Account} serviceAccount - the service account for your BigQuery package: https://cloud.google.com/iam/docs/service-accounts-create#creating\n* @returns {object[]} - A list of dastasets for a given project\n*/\nasync function listDatasets(serviceAccount) {\n  try {\n    const acc = await codeengine.getAccount(serviceAccount.id);\n    const keys = JSON.parse(acc.properties.serviceToken);\n    const url = `${baseAPI}/bigquery/v2/projects/${keys.project_id}/datasets`;\n    const response = await request(serviceAccount, {url});\n    return response.data.datasets;\n  } catch (e) {\n    console.error(e)\n    throw(e);\n  }\n}\n\n/**\n* Get the definition for a given datasetId\n*\n* @param {Account} serviceAccount - the service account for your BigQuery package: https://cloud.google.com/iam/docs/service-accounts-create#creating\n* @param {text} datasetId - the id of the dataset you wish to request\n* @returns {object} - The definition of a dataset\n*/\nasync function getDataset(serviceAccount, datasetId) {\n  try {\n    const acc = await codeengine.getAccount(serviceAccount.id);\n    const keys = JSON.parse(acc.properties.serviceToken);\n    const url = `${baseAPI}/bigquery/v2/projects/${keys.project_id}/datasets/${datasetId}`;\n    const response = await request(serviceAccount, {url});\n    return response.data;\n  } catch (e) {\n    console.error(e)\n    throw(e);\n  }\n}\n\n/**\n* Get a list of tables for a given dataset\n*\n* @param {Account} serviceAccount - the service account for your BigQuery package: https://cloud.google.com/iam/docs/service-accounts-create#creating\n* @param {text} datasetId - the id of the dataset you wish to request tables from\n* @returns {object[]} - A list of tables for a given dataset\n*/\nasync function listTables(serviceAccount, datasetId) { \n  try {\n    const acc = await codeengine.getAccount(serviceAccount.id);\n    const keys = JSON.parse(acc.properties.serviceToken);\n    const url = `${baseAPI}/bigquery/v2/projects/${keys.project_id}/datasets/${datasetId}/tables`;\n    const response = await request(serviceAccount, {url});\n    return response.data.tables;\n  } catch (e) {\n    console.error(e)\n    throw(e);\n  }\n}\n\n/**\n* Get the definition of an existing table\n*\n* @param {Account} serviceAccount - the service account for your BigQuery package: https://cloud.google.com/iam/docs/service-accounts-create#creating\n* @param {text} datasetId - the id of the dataset where the table resides\n* @param {text} tableId - the id of the table you wish to request\n* @returns {object} - The def ...
# ...
#  DocumentSource(environment='Code Engine', id='938bc05d-4bac-48cc-9647-727bc5f2fb0e', name='Dashboard Deduplication', design_id='938bc05d-4bac-48cc-9647-727bc5f2fb0e', design_name='Dashboard Deduplication', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='const codeengine = require(\'codeengine\');\n\n/**\n * Fetches all card IDs from a given page or dashboard and logs them to the console.\n *\n * @param {string} pageId - ID of the page or dashboard\n * @returns {Promise<void>}\n */\nasync function fetchAndLogCardIds(pageId) {\n  const fetchPageUrl = `api/content/v1/pages/${pageId}/cards`; // Endpoint to fetch all cards on a page\n\n  try {\n    // Fetch all card IDs from the page\n    const pageResponse = await codeengine.sendRequest(\'GET\', fetchPageUrl);\n    if (!pageResponse || pageResponse.length === 0) {\n      throw new Error(\'No cards found on the page\');\n    }\n\n    const cardIds = pageResponse.map(card => card.id);\n\n    console.log(\'Card IDs on the page:\', cardIds);\n  } catch (error) {\n    console.error(\'Error fetching card IDs:\', error); // Log the error for debugging\n    throw error;\n  }\n}\n\n/**\n * Changes the card title, removing the prefix "Duplicate of " if present\n *\n * @param {text} cardId - text id of card to update\n * @returns {boolean} - true if successful\n */\n\nasync function updateCardTitle(cardId) {\n  const fetchUrl = `api/content/v1/cards?urns=${cardId}&parts=metadata,metadataOverrides,problems,properties,certification,datasources,dateInfo,domoapp,drillPath,drillPathURNs,library,masonData,owner,owners,problems,properties,slicers&includeFiltered=true`; // Endpoint to fetch card details\n  const updateUrl = `/api/content/v1/cards/${cardId}/title`; // Endpoint to update card title\n\n  try {\n    // Fetch the current card details\n    const response = await codeengine.sendRequest(\'GET\', fetchUrl);\n    if (!response || response.length === 0) {\n      throw new Error(\'No card data found\');\n    }\n\n    const currentTitle = response[0].title;\n    if (!currentTitle) {\n      throw new Error(\'Title not found in card data\');\n    }\n\n    // Remove "Duplicate of " from the title\n    const newTitle = currentTitle.replace(/^Duplicate of /, \'\');\n\n    // Update the card with the new title\n    const payload = { title: newTitle };\n    await codeengine.sendRequest(\'PUT\', updateUrl, payload);\n\n    return true;\n  } catch (error) {\n    console.error(\'Error updating card title:\', error); // Log the error for debugging\n    throw error;\n  }\n}\n\n/**\n * Changes the card titles on page, removing the prefix "Duplicate of " if present\n *\n * @param {text} pageId - text id of page/dashboard to update\n * @returns {boolean} - true if successful\n */\n\nasync function updateAllCardTitles(pageId) {\n  const fetchPageUrl = `api/content/v1/pages/${pageId}/cards`; // Endpoint to fetch all cards on a page\n\n  try {\n    // Fetch all card IDs from the page\n    const pageResponse = await codeengine.sendRequest(\'GET\', fetchPageUrl);\n    if (!pageResponse || pageResponse.length === 0) {\n      throw new Error(\'No cards found on the page\');\n    }\n\n    const cardIds = pageResponse.map(card => card.id);\n\n    for (const cardId of cardIds) {\n      const fetchUrl = `api/content/v1/cards?urns=${cardId}&parts=metadata,metadataOverrides,problems,properties,certification,datasources,dateInfo,domoapp,drillPath,drillPathURNs,library,masonData,owner,owners,problems,properties,slicers&includeFiltered=true`; // Endpoint to fetch card details\n      const updateUrl = `/api/content/v1/cards/${cardId}/title`; // Endpoint to update card title\n\n      try {\n        // Fetch the current card details\n        const response = await codeengine.sendRequest(\'GET\', fetchUrl);\n        if (!response || response.length === 0) {\n          throw new Error(`No card data found for card ID: ${cardId}`);\n        }\n\n        const currentTitle = response[0].title;\n        if (!currentT ...
#  DocumentSource(environment='Code Engine', id='b55ebc56-a177-4a1d-8ab6-365ac7b7022f', name='NB Authentication', design_id='b55ebc56-a177-4a1d-8ab6-365ac7b7022f', design_name='NB Authentication', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='import codeengine\nimport json\nimport requests\n\ndef get_creds(account_name):\n    try:\n        creds = codeengine.get_account(account_name)\n        credentials = json.loads(creds["properties"]["credentials"])\n        return {\n            "DOMO_USERNAME": credentials["DOMO_USERNAME"],\n            "DOMO_PASSWORD": credentials["DOMO_PASSWORD"]\n        }\n    except Exception as e:\n        print(f"Error getting credentials: {e}")\n        return None\n\n\ndef getAuth(DOMO_USERNAME, DOMO_PASSWORD, domo_instance):\n    url = f\'https://{domo_instance}/api/content/v2/authentication\'\n    headers = {\n        \'Accept\': \'application/json\',\n        \'Content-Type\': \'application/json\'\n    }\n    payload = {\'method\': \'password\', \'emailAddress\': DOMO_USERNAME, \'password\': DOMO_PASSWORD}\n    response = requests.post(url, json=payload, headers=headers)\n\n    if response.status_code != 200:\n        print(f"Failed to authenticate. Status code: {response.status_code}")\n        return None\n\n    try:\n        dev_token = response.json().get(\'sessionToken\')\n    except json.JSONDecodeError as e:\n        print(f"Failed to parse JSON response: {e}")\n        return None\n\n    if dev_token is None:\n        print("Failed to authenticate. Check username and password.")\n\n    return dev_token', version='1.0.1', last_modified_dt='2024-05-03T19:04:44.274Z', domo_instance='domo-community', owner=DomoUser(id=958086679, display_name='nate sql', role_id=1, email='nate.bear@sony.com')),
#  DocumentSource(environment='Code Engine', id='ac26907e-0316-4407-9c34-514a29be280e', name='Update Date Variables', design_id='ac26907e-0316-4407-9c34-514a29be280e', design_name='Update Date Variables', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="function myFunction(param) {\n  console.log('Hello World!', param);\n}\n\nmodule.exports.myFunction = myFunction;", version='1.0.0', last_modified_dt='2024-04-30T20:54:36.897Z', domo_instance='domo-community', owner=DomoUser(id=68216396, display_name='Elliott Leonard', role_id=1, email='egleonard88@gmail.com')),
#  DocumentSource(environment='Code Engine', id='368f11de-524a-49d2-a29e-f334bc210f28', name='NB AppDb', design_id='368f11de-524a-49d2-a29e-f334bc210f28', design_name='NB AppDb', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='import json\nimport requests\n\ndef createObject(domo_instance, idp_id, company_id, user_name, email, role_name, role_id, event_timestamp, crte_user_output):\n    # Create a dictionary with the input variables\n    data_object = {\n        "domo_instance": domo_instance,\n        "idp_id": idp_id,\n        "company_id": company_id,\n        "user_name": user_name,\n        "email": email,\n        "role_name": role_name,\n        "role_id": role_id,\n        "event_timestamp": event_timestamp,\n        "crte_user_output": crte_user_output\n    }\n    return data_object\n\ndef appendToObjectList(list_of_object, new_object):\n    try:\n        # Append the new object to the list\n        list_of_object.append(new_object)\n        return list_of_object\n    except Exception as e:\n        print(f"Error appending object to list: {e}")\n        return None\n\ndef syncAppDB(domo_instance, datastoreId, dev_token):\n    url = f\'https://{domo_instance}/api/datastores/v1/export/{datastoreId}\'\n    headers = {\n        \'Accept\':\'application/json\',\n        \'Content-Type\':\'application/json\',\n        \'x-domo-authentication\': dev_token\n    }\n    response = requests.post(url, headers=headers)\n    return response.status_code', version='1.0.1', last_modified_dt='2024-04-12T18:45:29.414Z', domo_instance='domo-community', owner=DomoUser(id=958086679, display_name='nate sql', role_id=1, email='nate.bear@sony.com')),
#  DocumentSource(environment='Code Engine', id='5cb954fc-683d-4fb2-9798-40cc6b1946ca', name='NB Users and Roles', design_id='5cb954fc-683d-4fb2-9798-40cc6b1946ca', design_name='NB Users and Roles', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='import json\nimport requests\n\ndef getRoles(domo_instance, dev_token, role_name):\n    url = f\'https://{domo_instance}/api/authorization/v1/roles\'\n    headers = {\n        \'Accept\': \'application/json\',\n        \'x-domo-authentication\': dev_token\n    }\n    response = requests.get(url, headers=headers)\n    \n    if not response.ok:\n        print(f"Failed to get roles. Status code: {response.status_code}")\n        return None\n\n    roles = json.loads(response.text)\n    \n    # Find the role ID for the dynamic role name \n    role_id = None\n    for role in roles:\n        if role["name"] == role_name:\n            role_id = role["id"]\n            break\n          \n    if role_id is None:\n        print(f"Role \'{role_name}\' not found in the instance.")\n  \n    return role_id\n\n\n\ndef createUser(domo_instance, dev_token, name, email, roleId):\n    url = f\'https://{domo_instance}/api/content/v3/users?sendEmail=false\'\n    headers = {\n        \'Accept\': \'application/json\',\n        \'Content-Type\': \'application/json\',\n        \'x-domo-authentication\': dev_token\n    }\n    payload = {\n        "displayName": name,\n        "detail": {"email": email},\n        "roleId": roleId,\n        "sendInviteEmail": False\n    }\n    response = requests.post(url, headers=headers, json=payload)\n    return response.text\n\n\ndef get_values_from_json(row_data, action_fields):\n    try:\n      result = {}\n      for act_field in action_fields:\n          if act_field in row_data:\n              result[act_field] = row_data[act_field]\n      return result\n    except Exception as e:\n        print(f"Error processing JSON data: {e}")\n        return None      ', version='1.0.1', last_modified_dt='2024-04-12T18:43:11.716Z', domo_instance='domo-community', owner=DomoUser(id=958086679, display_name='nate sql', role_id=1, email='nate.bear@sony.com')),
#  DocumentSource(environment='Code Engine', id='fc484f87-4e05-45a5-8e1b-8f6fac8cac5b', name='python', design_id='fc484f87-4e05-45a5-8e1b-8f6fac8cac5b', design_name='python', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='def greeting(name): \n  print("Hello " + name)\n  return "Hello " + name', version='1.0.0', last_modified_dt='2024-04-12T18:16:54.380Z', domo_instance='domo-community', owner=DomoUser(id=1893952720, display_name='Jae Wilson1', role_id=810756122, email='jae@datacrew.space')),
#  DocumentSource(environment='Code Engine', id='37e449bf-52da-43ab-872e-361a643e13b6', name='TestPackage', design_id='37e449bf-52da-43ab-872e-361a643e13b6', design_name='TestPackage', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='def greeting(name): \n  print("Hello " + name)\n  return "Hello " + name', version='1.0.0', last_modified_dt='2024-03-10T18:34:04.573Z', domo_instance='domo-community', owner=DomoUser(id=1728973208, display_name='Peter Shull', role_id=2097317660, email='shullp05@gmail.com')),
#  DocumentSource(environment='Code Engine', id='57229f5b-5c27-4636-b419-c3753449a285', name='DOMO General Utilities', design_id='57229f5b-5c27-4636-b419-c3753449a285', design_name='DOMO General Utilities', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='/**\n * Converts a dataset response to a list of objects\n *\n * @param {Object} dsResponse The response from a dataset query\n * @param {Array} dsResponse.rows The rows of the dataset\n * @param {Array} dsResponse.columns The columns of the dataset\n * @returns {Array} The response from a dataset query as a list of objects\n */\nfunction convertDsResponseToList({ rows, columns }) {\n  return rows.map((row) =>\n    row.reduce((acc, curr, index) => ({ ...acc, [columns[index]]: curr }), {})\n  );\n}\n\n/**\n * Returns an empty array\n *\n * @returns {Array} An empty list\n */\nconst initializeListOfObjects = () => [];\n\n/**\n * Checks if the supplied email is valid\n *\n * @param {string} email The email address to validate\n * @returns {boolean} Whether the email address is valid\n */\nconst isValidEmail = (email) =>\n  /^[a-z0-9._%+-]+@[a-z0-9.-]+\\.[a-z]{2,}$/.test(email.toLowerCase());\n\n/**\n * Retrieve an object at the specified index\n *\n * @param {Array} list The list of objects to source from\n * @param {number} index The index of the object to get\n * @returns {Object} The object at the specified index\n */\nconst getObjectFromList = (list, index) => {\n  const value = list[index];\n\n  if (typeof value === "string") {\n    try {\n      return JSON.parse(value);\n    } catch (e) {\n      /* We do nothing cause it\'s not an object */\n    }\n  }\n\n  return typeof value === "object" && value !== null ? value : {};\n};\n\n/**\n * Retrieve the string at the specified index\n *\n * @param {Array} list The list of strings to source from\n * @param {number} index The index of the string to get\n * @returns {string} The string at the specified index\n */\nconst getStringFromList = (list, index) => {\n  const value = list[index];\n\n  if (typeof value === "object" && value !== null) return JSON.stringify(value);\n\n  return `${list[index]}`;\n};\n\n/**\n * Retrieve the value of the specified property on the provided object\n *\n * @param {Object} obj The object to access\n * @param {string} property The property to access\n * @returns {any} The value of the property on the object\n */\nconst getObjectFromObject = (obj, property) => {\n  try {\n    const value = property\n      .split(".")\n      .reduce((target, field) => (target ? target[field] : undefined), obj);\n\n    if (typeof value === "string") {\n      try {\n        return JSON.parse(value);\n      } catch (e) {\n        /* We do nothing cause it\'s not an object */\n      }\n    }\n\n    return typeof value === "object" && value !== null ? value : {};\n  } catch (error) {\n    console.error("Error occurred: ", error);\n    return {};\n  }\n};\n\n/**\n * Retrieve the value of the specified property on the provided object\n *\n * @param {Object} obj The object to access\n * @param {string} property The property to access\n * @returns {Array} The value of the property on the object\n */\nconst getListOfObjectsFromObject = (obj, property) => {\n  try {\n    const value = property\n      .split(".")\n      .reduce((target, field) => (target ? target[field] : undefined), obj);\n\n    if (!Array.isArray(value)) throw new Error("The result is not an array");\n    if (value.some((item) => typeof item !== "object"))\n      throw new Error("One or more items in the array are not objects");\n\n    return value;\n  } catch (error) {\n    console.error("Error occurred: ", error);\n    return [];\n  }\n};\n\n/**\n * Retrieve the value of the specified property on the provided object\n *\n * @param {Object} obj The object to access\n * @param {string} property The property to access\n * @returns {Array} The value of the property on the object\n */\nconst getListOfStringsFromObject = (obj, property) => {\n  try {\n ...
#  DocumentSource(environment='Code Engine', id='ecee4443-6d40-4bd1-9fe3-1b7cb1ad3b1f', name='Ellibot', design_id='ecee4443-6d40-4bd1-9fe3-1b7cb1ad3b1f', design_name='Ellibot', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code="function myFunction() {\n  console.log('Hello World!', param);\n}\n\nmodule.exports.myFunction = myFunction;", version='1.0.0', last_modified_dt='2023-12-20T16:40:04.512Z', domo_instance='domo-community', owner=DomoUser(id=68216396, display_name='Elliott Leonard', role_id=1, email='egleonard88@gmail.com'))]

# %%
document_sources.documents[0]
# Out:
# DocumentSource(environment='Code Engine', id='3b8f8181-fdbb-4948-b0c4-d6d27ff991d3', name='Hugging Face', design_id='3b8f8181-fdbb-4948-b0c4-d6d27ff991d3', design_name='Hugging Face', log_dt=datetime.datetime(2024, 7, 22, 11, 46, 22, 667609), code='from transformers import GPT2LMHeadModel, GPT2Tokenizer\nimport torch\n\ndef generate_text(input_text: str) -> str:\n    """\n    Generate text using the GPT-2 model based on input text.\n\n    Args:\n    input_text (str): Input text to seed the text generation.\n\n    Returns:\n    str: Generated text based on the input.\n    """\n    # Load the model and tokenizer\n    model = GPT2LMHeadModel.from_pretrained("gpt2")\n    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")\n\n    # Encode the input text\n    input_ids = tokenizer.encode(input_text, return_tensors="pt")\n\n    # Generate text using the model\n    output = model.generate(\n        input_ids,\n        max_length=100,\n        num_return_sequences=1,\n        pad_token_id=tokenizer.eos_token_id\n    )\n\n    # Decode the output\n    decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)\n\n    return decoded_output\n\n\n    return decoded_output\n\n# Example usage of the function\ninput_text = "Hello, what is today\'s date?"\nresult = generate_text(input_text)\nprint(result)\n', version='1.0.0', last_modified_dt='2024-07-20T12:14:01.139Z', domo_instance='domo-community', owner=DomoUser(id=1728973208, display_name='Peter Shull', role_id=2097317660, email='shullp05@gmail.com'))

# %%
document_sources.documents[0].__dict__
# Out:
# {'environment': 'Code Engine',
#  'id': '3b8f8181-fdbb-4948-b0c4-d6d27ff991d3',
#  'name': 'Hugging Face',
#  'design_id': '3b8f8181-fdbb-4948-b0c4-d6d27ff991d3',
#  'design_name': 'Hugging Face',
#  'log_dt': datetime.datetime(2024, 7, 22, 11, 46, 22, 667609),
#  'code': 'from transformers import GPT2LMHeadModel, GPT2Tokenizer\nimport torch\n\ndef generate_text(input_text: str) -> str:\n    """\n    Generate text using the GPT-2 model based on input text.\n\n    Args:\n    input_text (str): Input text to seed the text generation.\n\n    Returns:\n    str: Generated text based on the input.\n    """\n    # Load the model and tokenizer\n    model = GPT2LMHeadModel.from_pretrained("gpt2")\n    tokenizer = GPT2Tokenizer.from_pretrained("gpt2")\n\n    # Encode the input text\n    input_ids = tokenizer.encode(input_text, return_tensors="pt")\n\n    # Generate text using the model\n    output = model.generate(\n        input_ids,\n        max_length=100,\n        num_return_sequences=1,\n        pad_token_id=tokenizer.eos_token_id\n    )\n\n    # Decode the output\n    decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)\n\n    return decoded_output\n\n\n    return decoded_output\n\n# Example usage of the function\ninput_text = "Hello, what is today\'s date?"\nresult = generate_text(input_text)\nprint(result)\n',
#  'version': '1.0.0',
#  'last_modified_dt': '2024-07-20T12:14:01.139Z',
#  'domo_instance': 'domo-community',
#  'owner': DomoUser(id=1728973208, display_name='Peter Shull', role_id=2097317660, email='shullp05@gmail.com')}

# %%
#| hide


nbdev.nbdev_export('./monitoring.ipynb')
