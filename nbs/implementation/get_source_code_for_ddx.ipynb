# %%
from pprint import pprint

# %%
import os
import mbison.client.core as dmda

auth = dmda.DomoAuth(
    domo_instance=os.environ["DOMO_INSTANCE"],
    access_token=os.environ["DOMO_ACCESS_TOKEN"],
)
auth
# Out:
# DomoAuth(domo_instance='domo-community', username=None)

# %%
import mbison.feature.cards as dmac
import mbison.feature.appdb as dmdb


def get_source_code_collection_for_ddx(card_id, auth, debug_api : bool = False):
    """
    identifies the collection that stores the source code for a ddx brick

    note card metadata includes "domoapps" which identifies the datastore that feeds an app.
    the one or many collections can be associated with a datastore / app
    for ddx, the source code is stored in the collection 'ddx_app_client_code'
    """

    res = dmac.get_card_by_id(card_id = card_id, auth = auth, debug_api= debug_api)
    
    datastore_id = res.response['domoapp']['id']

    res = dmdb.get_collections(auth=auth, debug_api= debug_api,
                    datastore_id= datastore_id
                    )
    
    source_code_collection = next((obj for obj in res.response if obj['name'] == 'ddx_app_client_code' ),None)

    if not source_code_collection:
        raise Exception(f'unable to to retrieve source code collection for {card_id}')
    
    
    return source_code_collection

test_card_id = '421373262'
test_collection = get_source_code_collection_for_ddx(card_id = test_card_id, auth = auth, debug_api = False)
test_collection
# Out:
# {'id': '9699b866-056d-43ca-9c88-ce32f899d0e7',
#  'datastoreId': 'ad37089f-6772-4710-bcd0-aba812c0fe14',
#  'defaultPermissions': 'read,read_content',
#  'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#   'CREATE_CONTENT': ['domoapps.edit'],
#   'DELETE': ['domoapps.edit'],
#   'DELETE_CONTENT': ['domoapps.edit'],
#   'UPDATE': ['domoapps.edit'],
#   'UPDATE_CONTENT': ['domoapps.edit']},
#  'owner': 1950208331,
#  'name': 'ddx_app_client_code',
#  'datasourceId': None,
#  'schema': None,
#  'filters': None,
#  'syncEnabled': False,
#  'syncRequired': False,
#  'fullReplaceRequired': False,
#  'lastSync': None,
#  'createdOn': '2024-07-04T17:13:56.572Z',
#  'updatedOn': '2024-07-04T17:13:56.572Z',
#  'updatedBy': 1950208331}

# %%
def get_source_code_from_collection(collection_id, auth, debug_api : bool = False):
    """
    extracts the document in a collection containing the ddx source code
    will autmoatically handle collection_sharing if collection is not currently shared with authenticated user
    
    source code will always be stored in document.content.htmlBlank
    """
    
    source_code_document = None
    attempt = 0

    while not source_code_document and attempt <= 1:
        try:
            res = dmdb.query_collection_documents(auth=auth,
                                        debug_api= debug_api,
                                        collection_id = collection_id,query = {}
                                        )
    
            source_code_document = next((obj for obj in res.response 
                                        #  if obj['content'].get('htmlBlank')), 
                                        ), None)
            
            # print(source_code_document['content'].keys())

        except dmdb.AppDb_API_Exception: 
            user_id = auth.who_am_i()['id']
        
            dmdb.modify_collection_permissions(
                collection_id = collection_id,
                user_id=user_id,
                permission= dmdb.Collection_Permission_Enum.READ_CONTENT,
                auth = auth
            )

        attempt +=1

    # if not source_code_document:
    #     raise Exception(f"document containing 'htmlBlank' not retrieved from collection - {collection_id}")

    return source_code_document

    
get_source_code_from_collection(collection_id=test_collection['id'], auth = auth)
# Out:
# {'id': '038104d7-a988-43bc-a8ae-3630805fa149',
#  'datastoreId': 'ad37089f-6772-4710-bcd0-aba812c0fe14',
#  'collectionId': '9699b866-056d-43ca-9c88-ce32f899d0e7',
#  'syncRequired': True,
#  'owner': '1950208331',
#  'createdBy': '1950208331',
#  'createdOn': '2024-07-04T17:14:02.346Z',
#  'updatedOn': '2024-07-29T13:47:36.151Z',
#  'updatedBy': '1950208331',
#  'content': {'htmlBlank': {'js': '// DDX Bricks Wiki - See https://developer.domo.com/docs/ddx-bricks/getting-started-using-ddx-bricks\n// for tips on getting started, linking to Domo data and debugging your app\n \n//Available globals\nvar domo = window.domo; // For more on domo.js: https://developer.domo.com/docs/dev-studio-guides/domo-js#domo.get\nvar datasets = window.datasets;\n\n//Step 1. Select your dataset(s) . dataset0 will be the default alias but you can choose other datasets and alias via the dataset dropdown and select dataset options.\n//Current dataset alias is dataset0 and selected dataset is "EXAMPLE SALES DATA"\n\n\n//Step 2. Query your dataset(s): https://developer.domo.com/docs/dev-studio-references/data-api\nvar fields = []; // keeping empty requests all fields\nvar groupby = []; // keeping empty to not use groupby\nvar query = `/data/v1/${datasets[0]}?fields=${fields.join()}&groupby=${groupby.join()}`;\ndomo.get(query).then(handleResult);\n\n//set up max filters for header filters\n//custom max min header filter for header filters\nvar minMaxFilterEditor = function(cell, onRendered, success, cancel, editorParams){\n\n    var end;\n\n    var container = document.createElement("span");\n\n    //create and style inputs\n    var start = document.createElement("input");\n    start.setAttribute("type", "number");\n    start.setAttribute("placeholder", "Min");\n    start.setAttribute("min", 0);\n    start.setAttribute("max", 100);\n    start.style.padding = "4px";\n    start.style.width = "50%";\n    start.style.boxSizing = "border-box";\n\n    start.value = cell.getValue();\n\n    function buildValues(){\n        success({\n            start:start.value,\n            end:end.value,\n        });\n    }\n\n    function keypress(e){\n        if(e.keyCode == 13){\n            buildValues();\n        }\n\n        if(e.keyCode == 27){\n            cancel();\n        }\n    }\n\n    end = start.cloneNode();\n    end.setAttribute("placeholder", "Max");\n\n    start.addEventListener("change", buildValues);\n    start.addEventListener("blur", buildValues);\n    start.addEventListener("keydown", keypress);\n\n    end.addEventListener("change", buildValues);\n    end.addEventListener("blur", buildValues);\n    end.addEventListener("keydown", keypress);\n\n\n    container.appendChild(start);\n    container.appendChild(end);\n\n    return container;\n }\n\n//custom max min filter function\nfunction minMaxFilterFunction(headerValue, rowValue, rowData, filterParams){\n    //headerValue - the value of the header filter element\n    //rowValue - the value of the column in this row\n    //rowData - the data for the row being filtered\n    //filterParams - params object passed to the headerFilterFuncParams property\n\n        if(rowValue){\n            if(headerValue.start != ""){\n                if(headerValue.end != ""){\n                    return rowValue >= headerValue.start && rowValue <= headerValue.end;\n                }else{\n                    return rowValue >= headerValue.start;\n                }\n            }else{\n                if(headerValue.end != ""){\n                    return rowValue <= headerValue.end;\n                }\n            }\n        }\n\n    return true; //must return a boolean, true if it passes the filter.\n}\n\n//Step 3. Do something with the data from the query result\nfunction handleResult(data){\n  console && console.log(data);\nvar table = new Tabulator("#tabulator-table", {\n      data:data,\n      autoColumns:true, // This can be removed and code to call specific column info inserted.\n      autoColumnsDefinitions: function(definitions) {\n        //definitions - array of column definition objects\n          definitions.forEach((column) => {\n              column.headerFilter = true; // add header text filter to every column. \n              column.formatter = "input";\n          });\n          return definitions;\n       },\n      clipboard:true, //set to false to disable ctrl+C.  ...
#    'html': '<link href="https://unpkg.com/tabulator-tables@6.2.1/dist/css/tabulator_modern.min.css" rel="stylesheet">\r\n<script type="text/javascript" src="https://unpkg.com/tabulator-tables@6.2.1/dist/js/tabulator.min.js"></script>\r\n<script type="text/javascript" src="https://oss.sheetjs.com/sheetjs/xlsx.full.min.js"></script>\r\n<div id="tabulator-table"></div> <! -- must match table name in javascript in the "//Step 3. Do something with the data from the query result" Area --> \r\n<div>\r\n    <button id="download-csv">Download CSV</button> <! -- CSV Button to call csv export function --> \r\n    <button id="download-xlsx">Download XLSX</button><! -- Excel Button to call Excel export function --> \r\n</div>\r\n',
#    'css': ''}}}

# %%
from typing import Callable
import pandas as pd

def process_card(card_id, auth, debug_api : bool = False, process_card_source_code_document_fn:  Callable = None):
    collection = get_source_code_collection_for_ddx(card_id = card_id, auth = auth, debug_api = debug_api)

    source_code_document = get_source_code_from_collection(collection_id= collection['id'], auth = auth, debug_api = debug_api)

    if process_card_source_code_document_fn:
        return process_card_source_code_document_fn(source_code_document)
    
    return source_code_document


def process_card_source_code_document_fn(doc) :
    return {
        'created_on' : doc['createdOn'],
        'updated_on' : doc['updatedOn'],
        'ddx_type' : next(iter(doc['content'])),
        **doc['content'][next(iter(doc['content']))]
                          
    }

process_card(card_id=test_card_id, auth = auth, process_card_source_code_document_fn=process_card_source_code_document_fn)
# Out:
# {'created_on': '2024-07-04T17:14:02.346Z',
#  'updated_on': '2024-07-29T13:47:36.151Z',
#  'ddx_type': 'htmlBlank',
#  'js': '// DDX Bricks Wiki - See https://developer.domo.com/docs/ddx-bricks/getting-started-using-ddx-bricks\n// for tips on getting started, linking to Domo data and debugging your app\n \n//Available globals\nvar domo = window.domo; // For more on domo.js: https://developer.domo.com/docs/dev-studio-guides/domo-js#domo.get\nvar datasets = window.datasets;\n\n//Step 1. Select your dataset(s) . dataset0 will be the default alias but you can choose other datasets and alias via the dataset dropdown and select dataset options.\n//Current dataset alias is dataset0 and selected dataset is "EXAMPLE SALES DATA"\n\n\n//Step 2. Query your dataset(s): https://developer.domo.com/docs/dev-studio-references/data-api\nvar fields = []; // keeping empty requests all fields\nvar groupby = []; // keeping empty to not use groupby\nvar query = `/data/v1/${datasets[0]}?fields=${fields.join()}&groupby=${groupby.join()}`;\ndomo.get(query).then(handleResult);\n\n//set up max filters for header filters\n//custom max min header filter for header filters\nvar minMaxFilterEditor = function(cell, onRendered, success, cancel, editorParams){\n\n    var end;\n\n    var container = document.createElement("span");\n\n    //create and style inputs\n    var start = document.createElement("input");\n    start.setAttribute("type", "number");\n    start.setAttribute("placeholder", "Min");\n    start.setAttribute("min", 0);\n    start.setAttribute("max", 100);\n    start.style.padding = "4px";\n    start.style.width = "50%";\n    start.style.boxSizing = "border-box";\n\n    start.value = cell.getValue();\n\n    function buildValues(){\n        success({\n            start:start.value,\n            end:end.value,\n        });\n    }\n\n    function keypress(e){\n        if(e.keyCode == 13){\n            buildValues();\n        }\n\n        if(e.keyCode == 27){\n            cancel();\n        }\n    }\n\n    end = start.cloneNode();\n    end.setAttribute("placeholder", "Max");\n\n    start.addEventListener("change", buildValues);\n    start.addEventListener("blur", buildValues);\n    start.addEventListener("keydown", keypress);\n\n    end.addEventListener("change", buildValues);\n    end.addEventListener("blur", buildValues);\n    end.addEventListener("keydown", keypress);\n\n\n    container.appendChild(start);\n    container.appendChild(end);\n\n    return container;\n }\n\n//custom max min filter function\nfunction minMaxFilterFunction(headerValue, rowValue, rowData, filterParams){\n    //headerValue - the value of the header filter element\n    //rowValue - the value of the column in this row\n    //rowData - the data for the row being filtered\n    //filterParams - params object passed to the headerFilterFuncParams property\n\n        if(rowValue){\n            if(headerValue.start != ""){\n                if(headerValue.end != ""){\n                    return rowValue >= headerValue.start && rowValue <= headerValue.end;\n                }else{\n                    return rowValue >= headerValue.start;\n                }\n            }else{\n                if(headerValue.end != ""){\n                    return rowValue <= headerValue.end;\n                }\n            }\n        }\n\n    return true; //must return a boolean, true if it passes the filter.\n}\n\n//Step 3. Do something with the data from the query result\nfunction handleResult(data){\n  console && console.log(data);\nvar table = new Tabulator("#tabulator-table", {\n      data:data,\n      autoColumns:true, // This can be removed and code to call specific column info inserted.\n      autoColumnsDefinitions: function(definitions) {\n        //definitions - array of column definition objects\n          definitions.forEach((column) => {\n              column.headerFilter = true; // add header text filter to every column. \n              column.formatter = "input";\n          });\n          return definitions;\n       },\n      clipboard:true, //set to false to disable ctrl+C. Review here https://tabula ...
#  'html': '<link href="https://unpkg.com/tabulator-tables@6.2.1/dist/css/tabulator_modern.min.css" rel="stylesheet">\r\n<script type="text/javascript" src="https://unpkg.com/tabulator-tables@6.2.1/dist/js/tabulator.min.js"></script>\r\n<script type="text/javascript" src="https://oss.sheetjs.com/sheetjs/xlsx.full.min.js"></script>\r\n<div id="tabulator-table"></div> <! -- must match table name in javascript in the "//Step 3. Do something with the data from the query result" Area --> \r\n<div>\r\n    <button id="download-csv">Download CSV</button> <! -- CSV Button to call csv export function --> \r\n    <button id="download-xlsx">Download XLSX</button><! -- Excel Button to call Excel export function --> \r\n</div>\r\n',
#  'css': ''}

# %%
def download_ddx_source_code(
    source_code_document,
    download_folder,
    process_card_source_code_document_fn: Callable,
):
    source_code = process_card_source_code_document_fn(source_code_document)

    dmut.upsert_folder(folder_path=download_folder)

    with open(f"{download_folder}/index.html", "w+") as f:
        f.write(source_code["html"])

    with open(f"{download_folder}/app.js", "w+") as f:
        f.write(source_code["js"])

    with open(f"{download_folder}/styles.css", "w+") as f:
        f.write(source_code["css"])

    return True

# %%
import mbison.feature.enterprise_apps as dmea
import mbison.feature.cards as dmca
import mbison.feature.appdb as dmdb
import mbison.client.utils as dmut


def get_app_meta(app_id, auth, debug_api : bool = False):
    endpoint=  f'/domoapps/apps/v2/{app_id}'

    return dmda.domo_api_request(
        endpoint=endpoint, auth=auth, request_type="get", debug_api=debug_api
    )



def process_card(card_id, auth, base_folder: str , debug_api : bool = False, ):
    card_meta = dmca.get_card_by_id(card_id = card_id, auth = auth, debug_api= debug_api).response
        
    app_id = card_meta['domoapp']['id'] 
    
    collections = dmdb.get_collections(auth=auth, debug_api= False,
                      datastore_id = app_id
                      ).response
    
    app_meta = get_app_meta(app_id = app_id , auth = auth).response

    design_id = app_meta['designId']

    design_meta = dmea.get_design_by_id(auth = auth, design_id= design_id).response
    design_version = design_meta['latestVersion']

    ddx_collection = next((collection for collection in collections if collection['name'] == 'ddx_app_client_code'), None)


    source_code = None
    if not ddx_collection:
        source_code = dmea.get_design_source_code_by_version(
            auth=auth,
            design_id=design_id,
            version=design_version,
            debug_api=False,
            download_path= f"{base_folder}/{design_meta['name']}/{design_version}/app.zip",
        )

    else:
        source_code_document = get_source_code_from_collection(collection_id=ddx_collection['id'], auth = auth)
        
        download_folder = f"{os.path.join(base_folder , str(card_id))}/"

        download_ddx_source_code(source_code_document, download_folder=download_folder, process_card_source_code_document_fn = process_card_source_code_document_fn)

    return {'app_meta': app_meta, 'design_meta': design_meta, 'collections': collections , "source_code" : source_code}


test_card_id = '1405984654' # enterprise app
# test_card_id = '421373262' # ddx

pprint(process_card(test_card_id, auth, base_folder= '../../TEST/', debug_api= False))
# Out:
# done writing stream
# {'app_meta': {'accountMapping': [],
#               'actionMapping': [],
#               'collections': [],
#               'context': {'accountMapping': [],
#                           'actionMapping': [],
#                           'collections': [],
#                           'createdDate': '2022-12-02T17:29:22Z',
#                           'designId': '8c16c8ab-c068-4110-940b-f738d7146efc',
#                           'designVersion': None,
#                           'id': '908c9814-4b48-4ba2-8990-03423819de9c',
#                           'isDisabled': False,
#                           'lastModifiedDate': '2022-12-02T17:29:25Z',
#                           'mapping': [],
#                           'packageMapping': [],
#                           'workflowMapping': []},
#               'createdDate': '2022-12-02T17:29:25Z',
#               'designId': '8c16c8ab-c068-4110-940b-f738d7146efc',
#               'designVersion': None,
#               'id': '87784693-7e11-4f4e-9e20-50525b8fc6f6',
#               'mapping': []},
#  'collections': [],
#  'design_meta': {'createdBy': '1893952720',
#                  'createdDate': '2022-12-02T17:26:03Z',
#                  'creator': {'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#                              'detail': None,
#                              'displayName': 'Jae Wilson1',
#                              'id': 1893952720,
#                              'role': None,
#                              'roleId': 810756122},
#                  'deletedDate': None,
#                  'description': None,
#                  'hasThumbnail': None,
#                  'id': '8c16c8ab-c068-4110-940b-f738d7146efc',
#                  'instances': [],
#                  'latestVersion': '1.0.0',
#                  'name': 'nbdev_documentation',
#                  'owner': '1893952720',
#                  'owners': [{'avatarKey': None,
#                              'detail': None,
#                              'displayName': '8:26 - go to sleep',
#                              'id': 1216550715,
#                              'role': 'Privileged',
#                              'roleId': 2},
#                             {'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#                              'detail': None,
#                              'displayName': 'Jae Wilson1',
#                              'id': 1893952720,
#                              'role': None,
#                              'roleId': 810756122}],
#                  'referencingCards': [{'active': True,
#                                        'allowTableDrill': True,
#                                        'badgeUpdated': 1670002778000,
#                                        'created': 1670002165,
#                                        'creatorId': 1893952720,
#                                        'domoapp': {'id': '87784693-7e11-4f4e-9e20-50525b8fc6f6'},
#                                        'id': 1405984654,
#                                        'locked': False,
#                                        'ownerId': 1893952720,
#                                        'title': 'New Custom App',
#                                        'type': 'domoapp',
#                                        'urn': '1405984654'}],
#                  'trusted': False,
#                  'updatedBy': '1893952720',
#                  'updatedDate': '2022-12-02T17:39:38Z',
#                  'versions': [{'accountsMapping': [],
#                                'actionsMapping': [],
#                                'collectionsMapping': [],
#                                'createdBy': '1893952720',
#                                'createdDate': '2022-12-02T17:26:03Z',
#                                'datasetsMapping': [],
#                                'deletedDate': None,
#                                'designId': '8c16c8ab-c068-4110-940b-f738d7146efc',
#                                'draft': False,
#                                'flags': {},
#                                'fullpage': False,
#                                'id': 'aa9b35ca-7ff3-4848-bb5c-6afdbb9c0f92',
#                                'packagesMapping': [],
#                                'publicAssetsEnabled': True,
#                                'releasedDate': None,
#                                'scopes': [],
#                                'size': {'height': 1.0, 'width': 1.0},
#                                'trusted': False,
#                                'updatedBy': '1893952720',
#                                'updatedDate': '2022-12-02T17:39:38Z',
#                                'version': '1.0.0',
#                                'workflowsMapping': []}]},
#  'source_code': ResponseGetData(response=True,
#                                 is_success=True,
#                                 status=200,
#                                 download_path='..\\..\\TEST\\nbdev_documentation\\1.0.0\\app.zip')}

# %%
def get_all_domoapps(auth :dmda.DomoAuth, temp_limit = None):
    """searches adminsummary API for all cards with cardtype domoapp"""
    
    query = {
            "includeCardTypeClause": True,
            "cardTypes": ["domoapp"],
            "ascending": True,
            "orderBy": "cardTitle",
        }
    
    res = dmac.search_cards(auth = auth, query = query)

    if temp_limit:
        res.response = res.response[:temp_limit]
    
    cards = [ (dmac.get_card_by_id(obj['id'], auth = auth)).response for obj in res.response]
    
    print(f'{len(cards)} ddx bricks retrieved from {auth.domo_instance}')
    
    return cards


cards = get_all_domoapps(auth = auth, temp_limit= 10)[0:2]
# Out:
# 10 ddx bricks retrieverd from domo-community

# %%
def process_instance(
    auth: dmda.DomoAuth,
    base_folder : str,
    temp_limit=20,
):
    cards = get_all_domoapps(auth=auth, temp_limit=temp_limit)
    base_folder = f"{base_folder}/{auth.domo_instance}/"

    print(base_folder)
    
    return [
        process_card(
            card_id=card["id"],
            auth=auth,
            base_folder = base_folder
        )
        for card in cards
    ]


process_instance(
    auth=auth,
    temp_limit=10,
    base_folder = '../../TEST'
)
# Out:
# 10 ddx bricks retrieverd from domo-community
# ../../TEST/domo-community/
# done writing stream
# done writing stream
# [{'app_meta': {'id': 'aace1266-dc7f-42cb-8595-46069d91a703',
#    'context': {'id': '708cff46-2a20-4ddd-b6dc-eb7a457619c5',
#     'designId': '897f9ffc-1ce2-4247-94d3-7afcb0192abb',
#     'designVersion': '1.6.1',
#     'mapping': [{'alias': 'dataset0',
#       'dataSetId': '2b0016a7-02bd-45b4-a9fe-b33fbf5b365e',
#       'fields': [],
#       'dql': None},
#      {'alias': 'dataset1',
#       'dataSetId': 'b995e5ba-b1cc-4dff-89f7-d8949c0d0aad',
#       'fields': [],
#       'dql': None},
#      {'alias': 'dataset2',
#       'dataSetId': 'b995e5ba-b1cc-4dff-89f7-d8949c0d0aad',
#       'fields': [],
#       'dql': None}],
#     'collections': [],
#     'accountMapping': [],
#     'actionMapping': [],
#     'workflowMapping': [],
#     'packageMapping': [],
#     'createdDate': '2024-03-29T01:33:40Z',
#     'lastModifiedDate': '2024-03-29T01:51:12Z',
#     'isDisabled': False},
#    'createdDate': '2024-03-28T23:25:14Z',
#    'designId': '897f9ffc-1ce2-4247-94d3-7afcb0192abb',
#    'designVersion': '1.6.1',
#    'mapping': [{'alias': 'dataset0',
#      'dataSetId': '2b0016a7-02bd-45b4-a9fe-b33fbf5b365e',
#      'fields': [],
#      'dql': None},
#     {'alias': 'dataset1',
#      'dataSetId': 'b995e5ba-b1cc-4dff-89f7-d8949c0d0aad',
#      'fields': [],
#      'dql': None},
#     {'alias': 'dataset2',
#      'dataSetId': 'b995e5ba-b1cc-4dff-89f7-d8949c0d0aad',
#      'fields': [],
#      'dql': None}],
#    'collections': [],
#    'accountMapping': [],
#    'actionMapping': []},
#   'design_meta': {'id': '897f9ffc-1ce2-4247-94d3-7afcb0192abb',
#    'name': 'ddx-html-blank',
#    'owner': None,
#    'createdBy': None,
#    'createdDate': '2021-08-26T17:10:07Z',
#    'updatedBy': None,
#    'updatedDate': '2023-03-22T23:27:35Z',
#    'description': None,
#    'versions': [{'id': 'b6a9592e-3291-4a3f-b702-de3eb38fdea2',
#      'designId': '897f9ffc-1ce2-4247-94d3-7afcb0192abb',
#      'version': '1.5.1',
#      'draft': False,
#      'trusted': False,
#      'publicAssetsEnabled': True,
#      'scopes': [],
#      'datasetsMapping': [{'alias': 'dataset0',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset1',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset2',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None}],
#      'collectionsMapping': [{'name': 'ddx_app_client_code',
#        'defaultPermission': ['read', 'read_content'],
#        'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#         'UPDATE': ['domoapps.edit'],
#         'DELETE': ['domoapps.edit'],
#         'CREATE_CONTENT': ['domoapps.edit'],
#         'UPDATE_CONTENT': ['domoapps.edit'],
#         'DELETE_CONTENT': ['domoapps.edit']}}],
#      'accountsMapping': [],
#      'actionsMapping': [],
#      'workflowsMapping': [],
#      'packagesMapping': [],
#      'size': {'width': 6.0, 'height': 3.0},
#      'fullpage': True,
#      'flags': {'client-code-enabled': True},
#      'createdBy': None,
#      'createdDate': '2022-01-27T17:17:41Z',
#      'updatedBy': None,
#      'updatedDate': '2022-01-27T18:39:27Z',
#      'releasedDate': '2022-01-27T17:17:43Z',
#      'deletedDate': None},
#     {'id': 'bc5bc989-b544-4fc7-9962-60b75a5eca59',
#      'designId': '897f9ffc-1ce2-4247-94d3-7afcb0192abb',
#      'version': '1.6.1',
#      'draft': False,
#      'trusted': False,
#      'publicAssetsEnabled': True,
#      'scopes': [],
#      'datasetsMapping': [{'alias': 'dataset0',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset1',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset2',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None}],
#      'collectionsMapping': [{'name': 'ddx_app_client_code',
#        'defaultPermission': ['read', 'read_content'],
#        'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#         'CREATE_CONTENT': ['domoapps.edit'],
#         'DELETE': ['domoapps.edit'],
#         'DELETE_CONTENT': ['domoapps.edit'],
#         'UPDATE': ['domoapps.edit'],
#         'UPDATE_CONTENT': ['domoapps.edit']}}],
#      'accountsMapping': [],
#      'actionsMapping': [],
#      'workflowsMapping': [],
#      'packagesMapping': [],
#      'size': {'width': 6.0, 'height': 3.0},
#      'fullpage': True,
#      'flags': {'client-code-enabled': True},
#      'createdBy': None,
#      'createdDate': '2023-03-22T23:27:33Z',
#      'updatedBy': None,
#      'updatedDate': '2023-03-23T05:42:19Z',
#      'releasedDate': '2023-03-22T23:27:35Z',
#      'deletedDate': None}],
#    'latestVersion': '1.6.1',
#    'instances': [],
#    'referencingCards': [{'domoapp': {'id': '314d780d-a5a5-46c3-9bdd-2ea3c5ebc746'},
#      'urn': '1431311868',
#      'id': 1431311868,
#      'type': 'domoapp',
#      'created': 1721065492,
#      'badgeUpdated': 1722301763000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Updated JWalsh Tabulator table with Theme Support & Dropdown Filters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '6437e998-6914-4789-a44c-43245591e6a3'},
#      'urn': '1893920710',
#      'id': 1893920710,
#      'type': 'domoapp',
#      'created': 1684522532,
#      'badgeUpdated': 1720643156000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'UserManagement_v2',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '4ec4fab9-5004-463e-9877-d61266beb712'},
#      'urn': '917179242',
#      'id': 917179242,
#      'type': 'domoapp',
#      'created': 1679727849,
#      'badgeUpdated': 1679751573000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'description': '1. Please Enter the Column Name\n2. Select an Operand\n3. Type in the Values, use comma for multiple values and DO NOT give white spaces anywhere\n',
#      'title': 'pFilter Direct',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '150886e7-0150-4308-838c-20702c53f81e'},
#      'urn': '221444197',
#      'id': 221444197,
#      'type': 'domoapp',
#      'created': 1714336567,
#      'badgeUpdated': 1714336726000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '8bd82430-ebb9-4791-8d21-473f69fa5341'},
#      'urn': '567812870',
#      'id': 567812870,
#      'type': 'domoapp',
#      'created': 1679816019,
#      'badgeUpdated': 1680176163000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'title': 'pFilters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': True},
#     {'domoapp': {'id': '5ea8b2d4-177a-423f-8cd2-9db1576e1283'},
#      'urn': '517308151',
#      'id': 517308151,
#      'type': 'domoapp',
#      'created': 1721053711,
#      'badgeUpdated': 1721053711000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of QA Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '440e8494-0146-4fc0-908f-98e578a37a48'},
#      'urn': '347162524',
#      'id': 347162524,
#      'type': 'domoapp',
#      'created': 1684449916,
#      'badgeUpdated': 1684450802000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'DDX - linked',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '21419c4b-4dfe-4141-8a61-889710e0a105'},
#      'urn': '14129106',
#      'id': 14129106,
#      'type': 'domoapp',
#      'created': 1720723604,
#      'badgeUpdated': 1721053000000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'JWalsh Tabulator table with Theme Support',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '636f3db5-9b2b-4f2b-917b-82a5ce9bd9bf'},
#      'urn': '628264039',
#      'id': 628264039,
#      'type': 'domoapp',
#      'created': 1666729913,
#      'badgeUpdated': 1666729914000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '83b9256a-e0b1-45b8-b01e-57202fab23c9'},
#      'urn': '1656883369',
#      'id': 1656883369,
#      'type': 'domoapp',
#      'created': 1667407590,
#      'badgeUpdated': 1667407590000,
#      'creatorId': 475856860,
#      'ownerId': 475856860,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '0870dc76-e327-4ab3-a8df-6830b49ecd17'},
#      'urn': '184516739',
#      'id': 184516739,
#      'type': 'domoapp',
#      'created': 1666731732,
#      'badgeUpdated': 1667404447000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '97edf64e-6373-497f-8e0a-02092d7672e6'},
#      'urn': '611510638',
#      'id': 611510638,
#      'type': 'domoapp',
#      'created': 1679816002,
#      'badgeUpdated': 1679838533000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'title': 'pFilter Direct',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': True},
#     {'domoapp': {'id': '16c5912f-f5f2-4fee-bd7e-fd62f9237c5b'},
#      'urn': '1291313259',
#      'id': 1291313259,
#      'type': 'domoapp',
#      'created': 1684525085,
#      'badgeUpdated': 1684526723000,
#      'creatorId': 966365811,
#      'ownerId': 966365811,
#      'title': 'Top 10 Pages',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'e61b6072-ea2a-4ed0-a1ca-a430fadec4c9'},
#      'urn': '2084888098',
#      'id': 2084888098,
#      'type': 'domoapp',
#      'created': 1721918263,
#      'badgeUpdated': 1721918457000,
#      'creatorId': 1079474652,
#      'ownerId': 1079474652,
#      'title': 'Jace - blank brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '99c54caa-9790-489d-82a8-6e7f1fe073b8'},
#      'urn': '281906607',
#      'id': 281906607,
#      'type': 'domoapp',
#      'created': 1721053713,
#      'badgeUpdated': 1721065396000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'JWalsh Tabulator table with Theme Support & Dropdown Filters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c10d3708-2fb0-442b-a750-bc1ff7b435f7'},
#      'urn': '1476092118',
#      'id': 1476092118,
#      'type': 'domoapp',
#      'created': 1700519624,
#      'badgeUpdated': 1700519624000,
#      'creatorId': 152768850,
#      'ownerId': 152768850,
#      'title': 'Copy of 7 Day Average per 100K Population',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '2b7b1fe1-496c-4b0b-b0ac-672c555c31de'},
#      'urn': '687253373',
#      'id': 687253373,
#      'type': 'domoapp',
#      'created': 1667580409,
#      'badgeUpdated': 1667582873000,
#      'creatorId': 1768567034,
#      'ownerId': 1768567034,
#      'title': 'Ashleigh Stevenson',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'ad731e3c-294a-4c82-ad5a-a83462f2ee2e'},
#      'urn': '2075466101',
#      'id': 2075466101,
#      'type': 'domoapp',
#      'created': 1723036167,
#      'badgeUpdated': 1723036167000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of QA About Anything',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '0033ed50-38e5-4c9e-9ea3-a3690e067b6e'},
#      'urn': '384392015',
#      'id': 384392015,
#      'type': 'domoapp',
#      'created': 1719426943,
#      'badgeUpdated': 1722268466000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Filter Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '7b4d368e-ff5c-4679-9e5d-a3525fcf4def'},
#      'urn': '359062734',
#      'id': 359062734,
#      'type': 'domoapp',
#      'created': 1679729074,
#      'badgeUpdated': 1679750785000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'description': '1. Please Select a Dataset (Columns would populate automatically)\n2. Select a Column\n3. Select an Operand\n4. Type in the Values, use comma for multiple values and DO NOT give white spaces anywhere',
#      'title': 'pFilters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'e9656fe3-ebc7-46a3-a96c-2a27d154a1cf'},
#      'urn': '1729615192',
#      'id': 1729615192,
#      'type': 'domoapp',
#      'created': 1711569876,
#      'badgeUpdated': 1712953994000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '5a1f1cad-93c1-4896-80c5-329588728e0c'},
#      'urn': '1827614237',
#      'id': 1827614237,
#      'type': 'domoapp',
#      'created': 1693537394,
#      'badgeUpdated': 1693537495000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Snake',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'aace1266-dc7f-42cb-8595-46069d91a703'},
#      'urn': '528432108',
#      'id': 528432108,
#      'type': 'domoapp',
#      'created': 1711668314,
#      'badgeUpdated': 1711677072000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': '100 People',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '0ce3b237-5151-4ab6-93bf-085f6a6fe8da'},
#      'urn': '1892736925',
#      'id': 1892736925,
#      'type': 'domoapp',
#      'created': 1693537569,
#      'badgeUpdated': 1693539290000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Rock Paper Scissors',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '25577877-a7d2-4794-a80b-5f5f63442a26'},
#      'urn': '1077495811',
#      'id': 1077495811,
#      'type': 'domoapp',
#      'created': 1693537874,
#      'badgeUpdated': 1693537965000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Breakout',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '60cbb4b3-ee17-49f5-a497-9730181b6f33'},
#      'urn': '776528222',
#      'id': 776528222,
#      'type': 'domoapp',
#      'created': 1669923457,
#      'badgeUpdated': 1679685035000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '59540dfc-7a98-4376-8f52-b75c496b4919'},
#      'urn': '764036369',
#      'id': 764036369,
#      'type': 'domoapp',
#      'created': 1713882748,
#      'badgeUpdated': 1713909704000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '48b53068-0065-4457-9cdd-7ff113c5a3c7'},
#      'urn': '1117835546',
#      'id': 1117835546,
#      'type': 'domoapp',
#      'created': 1667509131,
#      'badgeUpdated': 1667510582000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'Earthquakes This Hour',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '3e56f930-0743-43da-90e6-bea1cf592cde'},
#      'urn': '1357807801',
#      'id': 1357807801,
#      'type': 'domoapp',
#      'created': 1667579517,
#      'badgeUpdated': 1667579618000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Solitaire',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '38b0a4b1-8ee8-4653-af66-db58c8630b89'},
#      'urn': '886023698',
#      'id': 886023698,
#      'type': 'domoapp',
#      'created': 1723036164,
#      'badgeUpdated': 1723036164000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of QA Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'd05b3a84-3ee4-421a-a003-5f8d7eca107f'},
#      'urn': '787191875',
#      'id': 787191875,
#      'type': 'domoapp',
#      'created': 1721655316,
#      'badgeUpdated': 1722447769000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Dynamic Nav Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '8d621578-b9f2-429c-8809-eee9cd886bde'},
#      'urn': '381051590',
#      'id': 381051590,
#      'type': 'domoapp',
#      'created': 1684525843,
#      'badgeUpdated': 1684526354000,
#      'creatorId': 966365811,
#      'ownerId': 966365811,
#      'title': 'Top 10 Pages with Access',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '02dd1577-6020-4ee5-ab11-3dd2dd206bd4'},
#      'urn': '885046139',
#      'id': 885046139,
#      'type': 'domoapp',
#      'created': 1720807778,
#      'badgeUpdated': 1722306817000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'QA About Anything',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'ad37089f-6772-4710-bcd0-aba812c0fe14'},
#      'urn': '421373262',
#      'id': 421373262,
#      'type': 'domoapp',
#      'created': 1720113236,
#      'badgeUpdated': 1722260857000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'description': 'This brick was created to be used as a easy use, duplicate, understand template.\nFor tabular documentations -- https://tabulator.info/examples/6.2\nFor walkthrough on creation of a tabulator brick like this -- https://developer.domo.com/portal/ndvsmatbqz5gk-game-night-planner-app-intro-to-domo-bricks ',
#      'title': 'Tabulator table with auto column generation, input text column filters, auto column width to data, movable columns, sort, csv and xl',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'f334c316-9334-46d2-b57f-04c0cc1a2408'},
#      'urn': '1275288477',
#      'id': 1275288477,
#      'type': 'domoapp',
#      'created': 1655751030,
#      'badgeUpdated': 1667359440000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'Display Timezones',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'd577f28d-8fb0-4b9e-8b3e-aa0fff6f43aa'},
#      'urn': '192319908',
#      'id': 192319908,
#      'type': 'domoapp',
#      'created': 1718217353,
#      'badgeUpdated': 1718217353000,
#      'creatorId': 1738612075,
#      'ownerId': 1738612075,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c3314265-965a-46b2-9e21-5ad27fd1101b'},
#      'urn': '577316875',
#      'id': 577316875,
#      'type': 'domoapp',
#      'created': 1683323666,
#      'badgeUpdated': 1698938285000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'New Custom App',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c8e090a7-7dbd-4094-b2f1-90e3e4eb09f5'},
#      'urn': '1337933137',
#      'id': 1337933137,
#      'type': 'domoapp',
#      'created': 1720634879,
#      'badgeUpdated': 1722301652000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'QA Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '523ae349-c1de-441f-ac6b-c0b5f6ec263a'},
#      'urn': '1869504318',
#      'id': 1869504318,
#      'type': 'domoapp',
#      'created': 1723036166,
#      'badgeUpdated': 1723036166000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of Updated JWalsh Tabulator table with Theme Support & Dropdown Filters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c865bfdd-220d-4e0c-baf9-eabc69df601d'},
#      'urn': '2131208053',
#      'id': 2131208053,
#      'type': 'domoapp',
#      'created': 1718116389,
#      'badgeUpdated': 1718117215000,
#      'creatorId': 1334846498,
#      'ownerId': 1334846498,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '02bd644f-f3de-421a-8455-97ae412c6994'},
#      'urn': '630260597',
#      'id': 630260597,
#      'type': 'domoapp',
#      'created': 1700519616,
#      'badgeUpdated': 1700519616000,
#      'creatorId': 152768850,
#      'ownerId': 152768850,
#      'title': 'Snow Depth (Percent of Historical Average)',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False}],
#    'owners': [{'id': 1079474652,
#      'displayName': 'Jace McLean',
#      'avatarKey': None,
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None},
#     {'id': 1334846498,
#      'displayName': 'Jonathan Pilafas',
#      'avatarKey': '0babf042-5f2d-4787-a105-9033198bfb30',
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None},
#     {'id': 152768850,
#      'displayName': 'Heath Pulham',
#      'avatarKey': None,
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None},
#     {'id': 1728973208,
#      'displayName': 'Peter Shull',
#      'avatarKey': '253079bc-8819-4753-882f-8687c78b2b1f',
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None},
#     {'id': 1738612075,
#      'displayName': 'Larry Mullins',
#      'avatarKey': None,
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None},
#     {'id': 1893952720,
#      'displayName': 'Jae Wilson1',
#      'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#      'role': None,
#      'roleId': 810756122,
#      'detail': None},
#     {'id': 1950208331,
#      'displayName': 'Justin Walsh',
#      'avatarKey': None,
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None},
#     {'id': 55874022,
#      'displayName': 'Grant Smith',
#      'avatarKey': '932c359c-5e94-40a4-8f0f-bb67e61b034d',
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None}],
#    'creator': None,
#    'deletedDate': None,
#    'trusted': False,
#    'hasThumbnail': None},
#   'collections': [{'id': '0cf07f0b-a6b7-464a-9db2-38a2ede0f3f7',
#     'datastoreId': 'aace1266-dc7f-42cb-8595-46069d91a703',
#     'defaultPermissions': 'read,read_content',
#     'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#      'CREATE_CONTENT': ['domoapps.edit'],
#      'DELETE': ['domoapps.edit'],
#      'DELETE_CONTENT': ['domoapps.edit'],
#      'UPDATE': ['domoapps.edit'],
#      'UPDATE_CONTENT': ['domoapps.edit']},
#     'owner': 1728973208,
#     'name': 'ddx_app_client_code',
#     'datasourceId': None,
#     'schema': None,
#     'filters': None,
#     'syncEnabled': False,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': None,
#     'createdOn': '2024-03-28T23:25:14.025Z',
#     'updatedOn': '2024-03-28T23:25:14.025Z',
#     'updatedBy': 1728973208}],
#   'source_code': None},
#  {'app_meta': {'id': '82f87dda-eeb8-4c1f-83b5-9e9b68d12d6a',
#    'context': {'id': 'a897ce8d-e404-4881-bdcd-8e428d3d12de',
#     'designId': 'a2bfbc19-0215-4611-9557-b2444cc2d418',
#     'designVersion': '1.6.0',
#     'mapping': [],
#     'collections': [],
#     'accountMapping': [],
#     'actionMapping': [],
#     'workflowMapping': [{'alias': 'workflow1',
#       'modelId': 'eb0de294-468a-4d2d-93b2-a4461243c465',
#       'version': '1.0.0',
#       'startName': 'Start Deduplicate Dashboard Card Titles',
#       'parameters': []}],
#     'packageMapping': [],
#     'createdDate': '2024-07-26T17:33:56Z',
#     'lastModifiedDate': '2024-07-26T17:35:07Z',
#     'isDisabled': False},
#    'createdDate': '2024-07-26T17:20:52Z',
#    'designId': 'a2bfbc19-0215-4611-9557-b2444cc2d418',
#    'designVersion': '1.6.0',
#    'mapping': [],
#    'collections': [],
#    'accountMapping': [],
#    'actionMapping': []},
#   'design_meta': {'id': 'a2bfbc19-0215-4611-9557-b2444cc2d418',
#    'name': 'ddx-workflow-start-form',
#    'owner': None,
#    'createdBy': None,
#    'createdDate': '2023-12-06T22:38:32Z',
#    'updatedBy': None,
#    'updatedDate': '2023-12-06T22:38:34Z',
#    'description': None,
#    'versions': [{'id': 'dc75a5be-43d9-4ec5-b503-5134446418d3',
#      'designId': 'a2bfbc19-0215-4611-9557-b2444cc2d418',
#      'version': '1.6.0',
#      'draft': False,
#      'trusted': False,
#      'publicAssetsEnabled': True,
#      'scopes': [],
#      'datasetsMapping': [],
#      'collectionsMapping': [{'name': 'ddx_app_client_code',
#        'defaultPermission': ['read', 'read_content'],
#        'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#         'CREATE_CONTENT': ['domoapps.edit'],
#         'DELETE': ['domoapps.edit'],
#         'DELETE_CONTENT': ['domoapps.edit'],
#         'UPDATE': ['domoapps.edit'],
#         'UPDATE_CONTENT': ['domoapps.edit']}}],
#      'accountsMapping': [],
#      'actionsMapping': [],
#      'workflowsMapping': [{'alias': 'workflow1',
#        'modelId': None,
#        'version': None,
#        'startName': None,
#        'parameters': []}],
#      'packagesMapping': [],
#      'size': {'width': 6.0, 'height': 3.0},
#      'fullpage': True,
#      'flags': {'client-code-enabled': True},
#      'createdBy': None,
#      'createdDate': '2023-12-06T22:38:32Z',
#      'updatedBy': None,
#      'updatedDate': '2023-12-06T22:49:51Z',
#      'releasedDate': '2023-12-06T22:38:34Z',
#      'deletedDate': None}],
#    'latestVersion': '1.6.0',
#    'instances': [],
#    'referencingCards': [{'domoapp': {'id': 'e8b99d7e-482a-4fee-a957-1b45eba88cba'},
#      'urn': '911051582',
#      'id': 911051582,
#      'type': 'domoapp',
#      'created': 1722014482,
#      'badgeUpdated': 1722015827000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Delete Dashboard From Domo',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'f86f0053-952b-41ff-829f-db8537e52ba0'},
#      'urn': '999612154',
#      'id': 999612154,
#      'type': 'domoapp',
#      'created': 1722014136,
#      'badgeUpdated': 1722015312000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Remove "Duplicate of " from all card names on dashboard',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'd6bb4cb1-daa9-4005-821d-b69aa5b0aa54'},
#      'urn': '594356525',
#      'id': 594356525,
#      'type': 'domoapp',
#      'created': 1722014471,
#      'badgeUpdated': 1722015662000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Revoke Page Access All Users (Keep Owners)',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '45819351-7915-449b-ad6f-8a6cc879720b'},
#      'urn': '1459998445',
#      'id': 1459998445,
#      'type': 'domoapp',
#      'created': 1722014428,
#      'badgeUpdated': 1722015351000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Remove "Duplicate of " from all card names and update datasource on dashboard',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '269fea32-b3d4-454e-8c90-4c9ff16203b0'},
#      'urn': '1340703676',
#      'id': 1340703676,
#      'type': 'domoapp',
#      'created': 1711381170,
#      'badgeUpdated': 1711381451000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'Workflow Start Form',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '8c43554f-204a-4fd5-922a-4d92428fcbcc'},
#      'urn': '1417035536',
#      'id': 1417035536,
#      'type': 'domoapp',
#      'created': 1722014512,
#      'badgeUpdated': 1722016275000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Clone User Access And Role (User already in Domo)',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '9a541ec0-03cc-4c8d-9ad1-3f1bc8bf78fe'},
#      'urn': '1458252555',
#      'id': 1458252555,
#      'type': 'domoapp',
#      'created': 1722014493,
#      'badgeUpdated': 1722016033000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Clone PDP from one dataset to another',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '82f87dda-eeb8-4c1f-83b5-9e9b68d12d6a'},
#      'urn': '1325872781',
#      'id': 1325872781,
#      'type': 'domoapp',
#      'created': 1722014452,
#      'badgeUpdated': 1722015283000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'title': 'Add user and group access from one dashboard to another while maintaining second dashboard users',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False}],
#    'owners': [{'id': 1893952720,
#      'displayName': 'Jae Wilson1',
#      'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#      'role': None,
#      'roleId': 810756122,
#      'detail': None},
#     {'id': 1950208331,
#      'displayName': 'Justin Walsh',
#      'avatarKey': None,
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None}],
#    'creator': None,
#    'deletedDate': None,
#    'trusted': False,
#    'hasThumbnail': None},
#   'collections': [{'id': '26c2293a-47af-41ac-ab13-242493e309f2',
#     'datastoreId': '82f87dda-eeb8-4c1f-83b5-9e9b68d12d6a',
#     'defaultPermissions': 'read,read_content',
#     'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#      'CREATE_CONTENT': ['domoapps.edit'],
#      'DELETE': ['domoapps.edit'],
#      'DELETE_CONTENT': ['domoapps.edit'],
#      'UPDATE': ['domoapps.edit'],
#      'UPDATE_CONTENT': ['domoapps.edit']},
#     'owner': 1950208331,
#     'name': 'ddx_app_client_code',
#     'datasourceId': None,
#     'schema': None,
#     'filters': None,
#     'syncEnabled': False,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': None,
#     'createdOn': '2024-07-26T17:20:52.121Z',
#     'updatedOn': '2024-07-26T17:20:52.121Z',
#     'updatedBy': 1950208331}],
#   'source_code': None},
#  {'app_meta': {'id': '97d8128b-6e91-4642-af9f-893b8cacd926',
#    'context': {'id': '0378432e-cdd2-41e9-a892-4c41d4ecfbab',
#     'designId': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#     'designVersion': '1.6.1',
#     'mapping': [{'alias': 'dataset0',
#       'dataSetId': '5cff4a60-8cd8-4037-b8ef-1d859d7baca4',
#       'fields': [],
#       'dql': None},
#      {'alias': 'dataset1',
#       'dataSetId': '5cff4a60-8cd8-4037-b8ef-1d859d7baca4',
#       'fields': [],
#       'dql': None},
#      {'alias': 'dataset2',
#       'dataSetId': '5cff4a60-8cd8-4037-b8ef-1d859d7baca4',
#       'fields': [],
#       'dql': None}],
#     'collections': [{'name': 'form_data',
#       'id': 'e6eabb0d-d2f8-4eb1-9e57-a90db77b1385'},
#      {'name': 'ddx_app_client_code',
#       'id': '946c78d8-ebe4-485a-9961-4c1cc15f1207'}],
#     'accountMapping': [],
#     'actionMapping': [],
#     'workflowMapping': [],
#     'packageMapping': [],
#     'createdDate': '2024-03-11T05:14:07Z',
#     'lastModifiedDate': '2024-03-11T05:14:07Z',
#     'isDisabled': False},
#    'createdDate': '2024-03-11T05:14:07Z',
#    'designId': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#    'designVersion': '1.6.1',
#    'mapping': [{'alias': 'dataset0',
#      'dataSetId': '5cff4a60-8cd8-4037-b8ef-1d859d7baca4',
#      'fields': [],
#      'dql': None},
#     {'alias': 'dataset1',
#      'dataSetId': '5cff4a60-8cd8-4037-b8ef-1d859d7baca4',
#      'fields': [],
#      'dql': None},
#     {'alias': 'dataset2',
#      'dataSetId': '5cff4a60-8cd8-4037-b8ef-1d859d7baca4',
#      'fields': [],
#      'dql': None}],
#    'collections': [{'name': 'form_data',
#      'id': 'e6eabb0d-d2f8-4eb1-9e57-a90db77b1385'},
#     {'name': 'ddx_app_client_code',
#      'id': '946c78d8-ebe4-485a-9961-4c1cc15f1207'}],
#    'accountMapping': [],
#    'actionMapping': []},
#   'design_meta': {'id': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#    'name': 'ddx-chat-gpt',
#    'owner': None,
#    'createdBy': None,
#    'createdDate': '2023-05-31T19:06:13Z',
#    'updatedBy': None,
#    'updatedDate': '2023-05-31T19:06:15Z',
#    'description': None,
#    'versions': [{'id': 'aa06ad7a-d4af-4bf3-94f8-88efcc5278cf',
#      'designId': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#      'version': '1.6.1',
#      'draft': False,
#      'trusted': False,
#      'publicAssetsEnabled': True,
#      'scopes': [],
#      'datasetsMapping': [{'alias': 'dataset0',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset1',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset2',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None}],
#      'collectionsMapping': [{'name': 'ddx_app_client_code',
#        'defaultPermission': ['read', 'read_content'],
#        'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#         'CREATE_CONTENT': ['domoapps.edit'],
#         'DELETE': ['domoapps.edit'],
#         'DELETE_CONTENT': ['domoapps.edit'],
#         'UPDATE': ['domoapps.edit'],
#         'UPDATE_CONTENT': ['domoapps.edit']}},
#       {'name': 'form_data',
#        'requiredAuthorities': {'CREATE_CONTENT': ['content.interactive'],
#         'DELETE_CONTENT': ['dataset.manage'],
#         'READ_CONTENT': ['content.interactive'],
#         'UPDATE_CONTENT': ['dataset.manage']}}],
#      'accountsMapping': [],
#      'actionsMapping': [],
#      'workflowsMapping': [],
#      'packagesMapping': [],
#      'size': {'width': 6.0, 'height': 3.0},
#      'fullpage': True,
#      'flags': {'client-code-enabled': True},
#      'createdBy': None,
#      'createdDate': '2023-05-31T19:06:13Z',
#      'updatedBy': None,
#      'updatedDate': '2023-05-31T19:09:14Z',
#      'releasedDate': '2023-05-31T19:06:15Z',
#      'deletedDate': None}],
#    'latestVersion': '1.6.1',
#    'instances': [],
#    'referencingCards': [{'domoapp': {'id': '97d8128b-6e91-4642-af9f-893b8cacd926'},
#      'urn': '1284766332',
#      'id': 1284766332,
#      'type': 'domoapp',
#      'created': 1710134047,
#      'badgeUpdated': 1710134047000,
#      'creatorId': 263469872,
#      'ownerId': 263469872,
#      'title': 'AI ChatGPT Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'a2693a83-a265-4a27-8a4f-a0d4778273ba'},
#      'urn': '1774801543',
#      'id': 1774801543,
#      'type': 'domoapp',
#      'created': 1709835985,
#      'badgeUpdated': 1721324158000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'AI ChatGPT Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False}],
#    'owners': [{'id': 1728973208,
#      'displayName': 'Peter Shull',
#      'avatarKey': '253079bc-8819-4753-882f-8687c78b2b1f',
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None},
#     {'id': 1893952720,
#      'displayName': 'Jae Wilson1',
#      'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#      'role': None,
#      'roleId': 810756122,
#      'detail': None},
#     {'id': 263469872,
#      'displayName': 'Daniel Ha',
#      'avatarKey': 'eea729d0-723d-47bf-9ab7-59210c590828',
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None}],
#    'creator': None,
#    'deletedDate': None,
#    'trusted': False,
#    'hasThumbnail': None},
#   'collections': [{'id': '946c78d8-ebe4-485a-9961-4c1cc15f1207',
#     'datastoreId': '97d8128b-6e91-4642-af9f-893b8cacd926',
#     'defaultPermissions': 'read,read_content',
#     'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#      'CREATE_CONTENT': ['domoapps.edit'],
#      'DELETE': ['domoapps.edit'],
#      'DELETE_CONTENT': ['domoapps.edit'],
#      'UPDATE': ['domoapps.edit'],
#      'UPDATE_CONTENT': ['domoapps.edit']},
#     'owner': 263469872,
#     'name': 'ddx_app_client_code',
#     'datasourceId': None,
#     'schema': None,
#     'filters': None,
#     'syncEnabled': False,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': None,
#     'createdOn': '2024-03-11T05:14:07.214Z',
#     'updatedOn': '2024-03-11T05:14:07.214Z',
#     'updatedBy': 263469872},
#    {'id': 'e6eabb0d-d2f8-4eb1-9e57-a90db77b1385',
#     'datastoreId': '97d8128b-6e91-4642-af9f-893b8cacd926',
#     'defaultPermissions': None,
#     'requiredAuthorities': {'CREATE_CONTENT': ['content.interactive'],
#      'DELETE_CONTENT': ['dataset.manage'],
#      'READ_CONTENT': ['content.interactive'],
#      'UPDATE_CONTENT': ['dataset.manage']},
#     'owner': 263469872,
#     'name': 'form_data',
#     'datasourceId': None,
#     'schema': {'columns': [{'type': 'STRING', 'name': 'prompt'},
#       {'type': 'STRING', 'name': 'response'}]},
#     'filters': None,
#     'syncEnabled': False,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': None,
#     'createdOn': '2024-03-11T05:14:07.072Z',
#     'updatedOn': '2024-03-11T05:14:14.885Z',
#     'updatedBy': 263469872}],
#   'source_code': None},
#  {'app_meta': {'id': 'a2693a83-a265-4a27-8a4f-a0d4778273ba',
#    'context': {'id': '56c1fab8-f3b7-4660-95aa-55e7e82058d6',
#     'designId': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#     'designVersion': '1.6.1',
#     'mapping': [{'alias': 'dataset0',
#       'dataSetId': '85566add-f95e-4abd-ad2d-73fbe9b582f6',
#       'fields': [],
#       'dql': None},
#      {'alias': 'dataset1',
#       'dataSetId': 'a4a6d58c-60d1-4889-a353-8a389815251f',
#       'fields': [],
#       'dql': None},
#      {'alias': 'dataset2',
#       'dataSetId': 'a4a6d58c-60d1-4889-a353-8a389815251f',
#       'fields': [],
#       'dql': None}],
#     'collections': [{'name': 'form_data',
#       'id': 'b4037606-c5d2-471f-b3ba-eea825aa008f'}],
#     'accountMapping': [],
#     'actionMapping': [],
#     'workflowMapping': [],
#     'packageMapping': [],
#     'createdDate': '2024-07-18T17:23:14Z',
#     'lastModifiedDate': '2024-07-18T17:35:57Z',
#     'isDisabled': False},
#    'createdDate': '2024-03-07T18:26:24Z',
#    'designId': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#    'designVersion': '1.6.1',
#    'mapping': [{'alias': 'dataset0',
#      'dataSetId': '85566add-f95e-4abd-ad2d-73fbe9b582f6',
#      'fields': [],
#      'dql': None},
#     {'alias': 'dataset1',
#      'dataSetId': 'a4a6d58c-60d1-4889-a353-8a389815251f',
#      'fields': [],
#      'dql': None},
#     {'alias': 'dataset2',
#      'dataSetId': 'a4a6d58c-60d1-4889-a353-8a389815251f',
#      'fields': [],
#      'dql': None}],
#    'collections': [{'name': 'form_data',
#      'id': 'b4037606-c5d2-471f-b3ba-eea825aa008f'}],
#    'accountMapping': [],
#    'actionMapping': []},
#   'design_meta': {'id': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#    'name': 'ddx-chat-gpt',
#    'owner': None,
#    'createdBy': None,
#    'createdDate': '2023-05-31T19:06:13Z',
#    'updatedBy': None,
#    'updatedDate': '2023-05-31T19:06:15Z',
#    'description': None,
#    'versions': [{'id': 'aa06ad7a-d4af-4bf3-94f8-88efcc5278cf',
#      'designId': 'f844d4cd-4f5c-415e-8248-97fe6512e992',
#      'version': '1.6.1',
#      'draft': False,
#      'trusted': False,
#      'publicAssetsEnabled': True,
#      'scopes': [],
#      'datasetsMapping': [{'alias': 'dataset0',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset1',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None},
#       {'alias': 'dataset2',
#        'dataSetId': '86baa242-2bd9-4e14-9ca5-3ee36a0346a1',
#        'fields': [],
#        'dql': None}],
#      'collectionsMapping': [{'name': 'ddx_app_client_code',
#        'defaultPermission': ['read', 'read_content'],
#        'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#         'CREATE_CONTENT': ['domoapps.edit'],
#         'DELETE': ['domoapps.edit'],
#         'DELETE_CONTENT': ['domoapps.edit'],
#         'UPDATE': ['domoapps.edit'],
#         'UPDATE_CONTENT': ['domoapps.edit']}},
#       {'name': 'form_data',
#        'requiredAuthorities': {'CREATE_CONTENT': ['content.interactive'],
#         'DELETE_CONTENT': ['dataset.manage'],
#         'READ_CONTENT': ['content.interactive'],
#         'UPDATE_CONTENT': ['dataset.manage']}}],
#      'accountsMapping': [],
#      'actionsMapping': [],
#      'workflowsMapping': [],
#      'packagesMapping': [],
#      'size': {'width': 6.0, 'height': 3.0},
#      'fullpage': True,
#      'flags': {'client-code-enabled': True},
#      'createdBy': None,
#      'createdDate': '2023-05-31T19:06:13Z',
#      'updatedBy': None,
#      'updatedDate': '2023-05-31T19:09:14Z',
#      'releasedDate': '2023-05-31T19:06:15Z',
#      'deletedDate': None}],
#    'latestVersion': '1.6.1',
#    'instances': [],
#    'referencingCards': [{'domoapp': {'id': '97d8128b-6e91-4642-af9f-893b8cacd926'},
#      'urn': '1284766332',
#      'id': 1284766332,
#      'type': 'domoapp',
#      'created': 1710134047,
#      'badgeUpdated': 1710134047000,
#      'creatorId': 263469872,
#      'ownerId': 263469872,
#      'title': 'AI ChatGPT Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'a2693a83-a265-4a27-8a4f-a0d4778273ba'},
#      'urn': '1774801543',
#      'id': 1774801543,
#      'type': 'domoapp',
#      'created': 1709835985,
#      'badgeUpdated': 1721324158000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'AI ChatGPT Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False}],
#    'owners': [{'id': 1728973208,
#      'displayName': 'Peter Shull',
#      'avatarKey': '253079bc-8819-4753-882f-8687c78b2b1f',
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None},
#     {'id': 1893952720,
#      'displayName': 'Jae Wilson1',
#      'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#      'role': None,
#      'roleId': 810756122,
#      'detail': None},
#     {'id': 263469872,
#      'displayName': 'Daniel Ha',
#      'avatarKey': 'eea729d0-723d-47bf-9ab7-59210c590828',
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None}],
#    'creator': None,
#    'deletedDate': None,
#    'trusted': False,
#    'hasThumbnail': None},
#   'collections': [{'id': '8de2f95a-5e86-474c-b83e-df63e2cc8474',
#     'datastoreId': 'a2693a83-a265-4a27-8a4f-a0d4778273ba',
#     'defaultPermissions': 'read,read_content',
#     'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#      'CREATE_CONTENT': ['domoapps.edit'],
#      'DELETE': ['domoapps.edit'],
#      'DELETE_CONTENT': ['domoapps.edit'],
#      'UPDATE': ['domoapps.edit'],
#      'UPDATE_CONTENT': ['domoapps.edit']},
#     'owner': 1728973208,
#     'name': 'ddx_app_client_code',
#     'datasourceId': None,
#     'schema': None,
#     'filters': None,
#     'syncEnabled': False,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': None,
#     'createdOn': '2024-03-07T18:26:24.831Z',
#     'updatedOn': '2024-03-07T18:26:24.831Z',
#     'updatedBy': 1728973208},
#    {'id': 'b4037606-c5d2-471f-b3ba-eea825aa008f',
#     'datastoreId': 'a2693a83-a265-4a27-8a4f-a0d4778273ba',
#     'defaultPermissions': None,
#     'requiredAuthorities': {'CREATE_CONTENT': ['content.interactive'],
#      'DELETE_CONTENT': ['dataset.manage'],
#      'READ_CONTENT': ['content.interactive'],
#      'UPDATE_CONTENT': ['dataset.manage']},
#     'owner': 1728973208,
#     'name': 'form_data',
#     'datasourceId': '7e8c4e24-6169-4e3b-ae51-65e4305b2e80',
#     'schema': {'columns': [{'type': 'STRING', 'name': 'prompt'},
#       {'type': 'STRING', 'name': 'response'}]},
#     'filters': None,
#     'syncEnabled': True,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': '2024-07-18T17:36:39.899Z',
#     'createdOn': '2024-03-07T18:26:24.696Z',
#     'updatedOn': '2024-07-18T17:36:40.894Z',
#     'updatedBy': 1728973208}],
#   'source_code': None},
#  {'app_meta': {'id': '7eccda8d-980d-4271-b142-5d7b3ba7fd14',
#    'context': {'id': '895e7b79-e928-40e6-8020-2f889f49a7c0',
#     'designId': 'fdbcd9e6-e58e-4d59-bb47-514676d5bef7',
#     'designVersion': None,
#     'mapping': [],
#     'collections': [{'name': '20240530_CommentsExample',
#       'id': '99795b42-e272-46ad-b66d-771d267bc1cd'}],
#     'accountMapping': [],
#     'actionMapping': [],
#     'workflowMapping': [],
#     'packageMapping': [],
#     'createdDate': '2024-05-30T13:17:38Z',
#     'lastModifiedDate': '2024-05-30T13:33:31Z',
#     'isDisabled': False},
#    'createdDate': '2024-05-30T13:11:01Z',
#    'designId': 'fdbcd9e6-e58e-4d59-bb47-514676d5bef7',
#    'designVersion': None,
#    'mapping': [],
#    'collections': [{'name': '20240530_CommentsExample',
#      'id': '99795b42-e272-46ad-b66d-771d267bc1cd'}],
#    'accountMapping': [],
#    'actionMapping': []},
#   'design_meta': {'id': 'fdbcd9e6-e58e-4d59-bb47-514676d5bef7',
#    'name': '20240530',
#    'owner': '475856860',
#    'createdBy': '475856860',
#    'createdDate': '2024-05-30T13:04:43Z',
#    'updatedBy': '475856860',
#    'updatedDate': '2024-05-30T13:33:07Z',
#    'description': None,
#    'versions': [{'id': '8c947eed-90f6-44c4-af60-02d025cb4b47',
#      'designId': 'fdbcd9e6-e58e-4d59-bb47-514676d5bef7',
#      'version': '1.0.0',
#      'draft': False,
#      'trusted': False,
#      'publicAssetsEnabled': True,
#      'scopes': [],
#      'datasetsMapping': [],
#      'collectionsMapping': [{'name': '20240530_CommentsExample',
#        'schema': {'columns': [{'type': 'STRING', 'name': 'comment'}]},
#        'syncEnabled': True}],
#      'accountsMapping': [],
#      'actionsMapping': [],
#      'workflowsMapping': [],
#      'packagesMapping': [],
#      'size': {'width': 5.0, 'height': 4.0},
#      'fullpage': False,
#      'flags': {},
#      'createdBy': '475856860',
#      'createdDate': '2024-05-30T13:04:43Z',
#      'updatedBy': '475856860',
#      'updatedDate': '2024-05-30T13:33:07Z',
#      'releasedDate': None,
#      'deletedDate': None}],
#    'latestVersion': '1.0.0',
#    'instances': [],
#    'referencingCards': [{'domoapp': {'id': '7eccda8d-980d-4271-b142-5d7b3ba7fd14'},
#      'urn': '768164427',
#      'id': 768164427,
#      'type': 'domoapp',
#      'created': 1717074661,
#      'badgeUpdated': 1717075390000,
#      'creatorId': 475856860,
#      'ownerId': 475856860,
#      'description': '',
#      'title': 'APP 2034590',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'f1c8bfec-d7e9-4ed4-944d-fcb71293b04e'},
#      'urn': '730626663',
#      'id': 730626663,
#      'type': 'domoapp',
#      'created': 1717076109,
#      'badgeUpdated': 1717076109000,
#      'creatorId': 475856860,
#      'ownerId': 475856860,
#      'title': 'App Instance #2',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False}],
#    'owners': [{'id': 1216550715,
#      'displayName': '8:26 - go to sleep',
#      'avatarKey': None,
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None},
#     {'id': 1893952720,
#      'displayName': 'Jae Wilson1',
#      'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#      'role': None,
#      'roleId': 810756122,
#      'detail': None},
#     {'id': 475856860,
#      'displayName': 'Noah Finberg',
#      'avatarKey': '85e3923f-14cc-4732-a20d-ceeb9d3de846',
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None}],
#    'creator': {'id': 475856860,
#     'displayName': 'Noah Finberg',
#     'avatarKey': '85e3923f-14cc-4732-a20d-ceeb9d3de846',
#     'role': 'Admin',
#     'roleId': 1,
#     'detail': None},
#    'deletedDate': None,
#    'trusted': False,
#    'hasThumbnail': None},
#   'collections': [{'id': '99795b42-e272-46ad-b66d-771d267bc1cd',
#     'datastoreId': '7eccda8d-980d-4271-b142-5d7b3ba7fd14',
#     'defaultPermissions': None,
#     'requiredAuthorities': None,
#     'owner': 475856860,
#     'name': '20240530_CommentsExample',
#     'datasourceId': '4a1a4f81-bdc1-4d35-8b75-d90637fa6ea5',
#     'schema': {'columns': [{'type': 'STRING', 'name': 'comment'}]},
#     'filters': None,
#     'syncEnabled': True,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': '2024-05-30T13:38:09.020Z',
#     'createdOn': '2024-05-30T13:11:01.503Z',
#     'updatedOn': '2024-05-30T13:38:09.287Z',
#     'updatedBy': 475856860}],
#   'source_code': ResponseGetData(response=True, is_success=True, status=200, download_path='..\\..\\TEST\\domo-community\\20240530\\1.0.0\\app.zip')},
#  {'app_meta': {'id': 'f1c8bfec-d7e9-4ed4-944d-fcb71293b04e',
#    'context': {'id': '74433b21-fc40-47ff-8a67-fb7737a1e242',
#     'designId': 'fdbcd9e6-e58e-4d59-bb47-514676d5bef7',
#     'designVersion': None,
#     'mapping': [],
#     'collections': [{'name': '20240530_CommentsExample'}],
#     'accountMapping': [],
#     'actionMapping': [],
#     'workflowMapping': [],
#     'packageMapping': [],
# ...
#      'badgeUpdated': 1721053711000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of QA Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '440e8494-0146-4fc0-908f-98e578a37a48'},
#      'urn': '347162524',
#      'id': 347162524,
#      'type': 'domoapp',
#      'created': 1684449916,
#      'badgeUpdated': 1684450802000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'DDX - linked',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '21419c4b-4dfe-4141-8a61-889710e0a105'},
#      'urn': '14129106',
#      'id': 14129106,
#      'type': 'domoapp',
#      'created': 1720723604,
#      'badgeUpdated': 1721053000000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'JWalsh Tabulator table with Theme Support',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '636f3db5-9b2b-4f2b-917b-82a5ce9bd9bf'},
#      'urn': '628264039',
#      'id': 628264039,
#      'type': 'domoapp',
#      'created': 1666729913,
#      'badgeUpdated': 1666729914000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '83b9256a-e0b1-45b8-b01e-57202fab23c9'},
#      'urn': '1656883369',
#      'id': 1656883369,
#      'type': 'domoapp',
#      'created': 1667407590,
#      'badgeUpdated': 1667407590000,
#      'creatorId': 475856860,
#      'ownerId': 475856860,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '0870dc76-e327-4ab3-a8df-6830b49ecd17'},
#      'urn': '184516739',
#      'id': 184516739,
#      'type': 'domoapp',
#      'created': 1666731732,
#      'badgeUpdated': 1667404447000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '97edf64e-6373-497f-8e0a-02092d7672e6'},
#      'urn': '611510638',
#      'id': 611510638,
#      'type': 'domoapp',
#      'created': 1679816002,
#      'badgeUpdated': 1679838533000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'title': 'pFilter Direct',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': True},
#     {'domoapp': {'id': '16c5912f-f5f2-4fee-bd7e-fd62f9237c5b'},
#      'urn': '1291313259',
#      'id': 1291313259,
#      'type': 'domoapp',
#      'created': 1684525085,
#      'badgeUpdated': 1684526723000,
#      'creatorId': 966365811,
#      'ownerId': 966365811,
#      'title': 'Top 10 Pages',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'e61b6072-ea2a-4ed0-a1ca-a430fadec4c9'},
#      'urn': '2084888098',
#      'id': 2084888098,
#      'type': 'domoapp',
#      'created': 1721918263,
#      'badgeUpdated': 1721918457000,
#      'creatorId': 1079474652,
#      'ownerId': 1079474652,
#      'title': 'Jace - blank brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '99c54caa-9790-489d-82a8-6e7f1fe073b8'},
#      'urn': '281906607',
#      'id': 281906607,
#      'type': 'domoapp',
#      'created': 1721053713,
#      'badgeUpdated': 1721065396000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'JWalsh Tabulator table with Theme Support & Dropdown Filters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c10d3708-2fb0-442b-a750-bc1ff7b435f7'},
#      'urn': '1476092118',
#      'id': 1476092118,
#      'type': 'domoapp',
#      'created': 1700519624,
#      'badgeUpdated': 1700519624000,
#      'creatorId': 152768850,
#      'ownerId': 152768850,
#      'title': 'Copy of 7 Day Average per 100K Population',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '2b7b1fe1-496c-4b0b-b0ac-672c555c31de'},
#      'urn': '687253373',
#      'id': 687253373,
#      'type': 'domoapp',
#      'created': 1667580409,
#      'badgeUpdated': 1667582873000,
#      'creatorId': 1768567034,
#      'ownerId': 1768567034,
#      'title': 'Ashleigh Stevenson',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'ad731e3c-294a-4c82-ad5a-a83462f2ee2e'},
#      'urn': '2075466101',
#      'id': 2075466101,
#      'type': 'domoapp',
#      'created': 1723036167,
#      'badgeUpdated': 1723036167000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of QA About Anything',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '0033ed50-38e5-4c9e-9ea3-a3690e067b6e'},
#      'urn': '384392015',
#      'id': 384392015,
#      'type': 'domoapp',
#      'created': 1719426943,
#      'badgeUpdated': 1722268466000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Filter Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '7b4d368e-ff5c-4679-9e5d-a3525fcf4def'},
#      'urn': '359062734',
#      'id': 359062734,
#      'type': 'domoapp',
#      'created': 1679729074,
#      'badgeUpdated': 1679750785000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'description': '1. Please Select a Dataset (Columns would populate automatically)\n2. Select a Column\n3. Select an Operand\n4. Type in the Values, use comma for multiple values and DO NOT give white spaces anywhere',
#      'title': 'pFilters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'e9656fe3-ebc7-46a3-a96c-2a27d154a1cf'},
#      'urn': '1729615192',
#      'id': 1729615192,
#      'type': 'domoapp',
#      'created': 1711569876,
#      'badgeUpdated': 1712953994000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '5a1f1cad-93c1-4896-80c5-329588728e0c'},
#      'urn': '1827614237',
#      'id': 1827614237,
#      'type': 'domoapp',
#      'created': 1693537394,
#      'badgeUpdated': 1693537495000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Snake',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'aace1266-dc7f-42cb-8595-46069d91a703'},
#      'urn': '528432108',
#      'id': 528432108,
#      'type': 'domoapp',
#      'created': 1711668314,
#      'badgeUpdated': 1711677072000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': '100 People',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '0ce3b237-5151-4ab6-93bf-085f6a6fe8da'},
#      'urn': '1892736925',
#      'id': 1892736925,
#      'type': 'domoapp',
#      'created': 1693537569,
#      'badgeUpdated': 1693539290000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Rock Paper Scissors',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '25577877-a7d2-4794-a80b-5f5f63442a26'},
#      'urn': '1077495811',
#      'id': 1077495811,
#      'type': 'domoapp',
#      'created': 1693537874,
#      'badgeUpdated': 1693537965000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Breakout',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '60cbb4b3-ee17-49f5-a497-9730181b6f33'},
#      'urn': '776528222',
#      'id': 776528222,
#      'type': 'domoapp',
#      'created': 1669923457,
#      'badgeUpdated': 1679685035000,
#      'creatorId': 1345737456,
#      'ownerId': 1345737456,
#      'title': 'DDX Blank',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '59540dfc-7a98-4376-8f52-b75c496b4919'},
#      'urn': '764036369',
#      'id': 764036369,
#      'type': 'domoapp',
#      'created': 1713882748,
#      'badgeUpdated': 1713909704000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '48b53068-0065-4457-9cdd-7ff113c5a3c7'},
#      'urn': '1117835546',
#      'id': 1117835546,
#      'type': 'domoapp',
#      'created': 1667509131,
#      'badgeUpdated': 1667510582000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'Earthquakes This Hour',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '3e56f930-0743-43da-90e6-bea1cf592cde'},
#      'urn': '1357807801',
#      'id': 1357807801,
#      'type': 'domoapp',
#      'created': 1667579517,
#      'badgeUpdated': 1667579618000,
#      'creatorId': 55874022,
#      'ownerId': 55874022,
#      'title': 'DDX Solitaire',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '38b0a4b1-8ee8-4653-af66-db58c8630b89'},
#      'urn': '886023698',
#      'id': 886023698,
#      'type': 'domoapp',
#      'created': 1723036164,
#      'badgeUpdated': 1723036164000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of QA Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'd05b3a84-3ee4-421a-a003-5f8d7eca107f'},
#      'urn': '787191875',
#      'id': 787191875,
#      'type': 'domoapp',
#      'created': 1721655316,
#      'badgeUpdated': 1722447769000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Dynamic Nav Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '8d621578-b9f2-429c-8809-eee9cd886bde'},
#      'urn': '381051590',
#      'id': 381051590,
#      'type': 'domoapp',
#      'created': 1684525843,
#      'badgeUpdated': 1684526354000,
#      'creatorId': 966365811,
#      'ownerId': 966365811,
#      'title': 'Top 10 Pages with Access',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '02dd1577-6020-4ee5-ab11-3dd2dd206bd4'},
#      'urn': '885046139',
#      'id': 885046139,
#      'type': 'domoapp',
#      'created': 1720807778,
#      'badgeUpdated': 1722306817000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'QA About Anything',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'ad37089f-6772-4710-bcd0-aba812c0fe14'},
#      'urn': '421373262',
#      'id': 421373262,
#      'type': 'domoapp',
#      'created': 1720113236,
#      'badgeUpdated': 1722260857000,
#      'creatorId': 1950208331,
#      'ownerId': 1950208331,
#      'description': 'This brick was created to be used as a easy use, duplicate, understand template.\nFor tabular documentations -- https://tabulator.info/examples/6.2\nFor walkthrough on creation of a tabulator brick like this -- https://developer.domo.com/portal/ndvsmatbqz5gk-game-night-planner-app-intro-to-domo-bricks ',
#      'title': 'Tabulator table with auto column generation, input text column filters, auto column width to data, movable columns, sort, csv and xl',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'f334c316-9334-46d2-b57f-04c0cc1a2408'},
#      'urn': '1275288477',
#      'id': 1275288477,
#      'type': 'domoapp',
#      'created': 1655751030,
#      'badgeUpdated': 1667359440000,
#      'creatorId': 68216396,
#      'ownerId': 68216396,
#      'title': 'Display Timezones',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'd577f28d-8fb0-4b9e-8b3e-aa0fff6f43aa'},
#      'urn': '192319908',
#      'id': 192319908,
#      'type': 'domoapp',
#      'created': 1718217353,
#      'badgeUpdated': 1718217353000,
#      'creatorId': 1738612075,
#      'ownerId': 1738612075,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c3314265-965a-46b2-9e21-5ad27fd1101b'},
#      'urn': '577316875',
#      'id': 577316875,
#      'type': 'domoapp',
#      'created': 1683323666,
#      'badgeUpdated': 1698938285000,
#      'creatorId': 1893952720,
#      'ownerId': 1893952720,
#      'title': 'New Custom App',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c8e090a7-7dbd-4094-b2f1-90e3e4eb09f5'},
#      'urn': '1337933137',
#      'id': 1337933137,
#      'type': 'domoapp',
#      'created': 1720634879,
#      'badgeUpdated': 1722301652000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'QA Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '523ae349-c1de-441f-ac6b-c0b5f6ec263a'},
#      'urn': '1869504318',
#      'id': 1869504318,
#      'type': 'domoapp',
#      'created': 1723036166,
#      'badgeUpdated': 1723036166000,
#      'creatorId': 1728973208,
#      'ownerId': 1728973208,
#      'title': 'Duplicate of Updated JWalsh Tabulator table with Theme Support & Dropdown Filters',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': 'c865bfdd-220d-4e0c-baf9-eabc69df601d'},
#      'urn': '2131208053',
#      'id': 2131208053,
#      'type': 'domoapp',
#      'created': 1718116389,
#      'badgeUpdated': 1718117215000,
#      'creatorId': 1334846498,
#      'ownerId': 1334846498,
#      'title': 'Blank Brick',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False},
#     {'domoapp': {'id': '02bd644f-f3de-421a-8455-97ae412c6994'},
#      'urn': '630260597',
#      'id': 630260597,
#      'type': 'domoapp',
#      'created': 1700519616,
#      'badgeUpdated': 1700519616000,
#      'creatorId': 152768850,
#      'ownerId': 152768850,
#      'title': 'Snow Depth (Percent of Historical Average)',
#      'active': True,
#      'allowTableDrill': True,
#      'locked': False}],
#    'owners': [{'id': 1079474652,
#      'displayName': 'Jace McLean',
#      'avatarKey': None,
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None},
#     {'id': 1334846498,
#      'displayName': 'Jonathan Pilafas',
#      'avatarKey': '0babf042-5f2d-4787-a105-9033198bfb30',
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None},
#     {'id': 152768850,
#      'displayName': 'Heath Pulham',
#      'avatarKey': None,
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None},
#     {'id': 1728973208,
#      'displayName': 'Peter Shull',
#      'avatarKey': '253079bc-8819-4753-882f-8687c78b2b1f',
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None},
#     {'id': 1738612075,
#      'displayName': 'Larry Mullins',
#      'avatarKey': None,
#      'role': 'Privileged',
#      'roleId': 2,
#      'detail': None},
#     {'id': 1893952720,
#      'displayName': 'Jae Wilson1',
#      'avatarKey': 'c605f478-0cd2-4451-9fd4-d82090b71e66',
#      'role': None,
#      'roleId': 810756122,
#      'detail': None},
#     {'id': 1950208331,
#      'displayName': 'Justin Walsh',
#      'avatarKey': None,
#      'role': None,
#      'roleId': 2097317660,
#      'detail': None},
#     {'id': 55874022,
#      'displayName': 'Grant Smith',
#      'avatarKey': '932c359c-5e94-40a4-8f0f-bb67e61b034d',
#      'role': 'Admin',
#      'roleId': 1,
#      'detail': None}],
#    'creator': None,
#    'deletedDate': None,
#    'trusted': False,
#    'hasThumbnail': None},
#   'collections': [{'id': 'ab36ebcd-9875-4ecd-a44f-e55a0b3f86e9',
#     'datastoreId': 'e9656fe3-ebc7-46a3-a96c-2a27d154a1cf',
#     'defaultPermissions': 'read,read_content',
#     'requiredAuthorities': {'CREATE': ['domoapps.edit'],
#      'CREATE_CONTENT': ['domoapps.edit'],
#      'DELETE': ['domoapps.edit'],
#      'DELETE_CONTENT': ['domoapps.edit'],
#      'UPDATE': ['domoapps.edit'],
#      'UPDATE_CONTENT': ['domoapps.edit']},
#     'owner': 1728973208,
#     'name': 'ddx_app_client_code',
#     'datasourceId': None,
#     'schema': None,
#     'filters': None,
#     'syncEnabled': False,
#     'syncRequired': False,
#     'fullReplaceRequired': False,
#     'lastSync': None,
#     'createdOn': '2024-03-27T20:04:36.413Z',
#     'updatedOn': '2024-03-27T20:04:36.413Z',
#     'updatedBy': 1728973208}],
#   'source_code': None}]
